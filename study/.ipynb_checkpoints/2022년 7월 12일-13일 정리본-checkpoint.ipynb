# %%
# 사용할 모듈 불러오기 
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import re
import xgboost

# %%
# 데이터 불러오기
items = pd.read_csv("./data/items.csv")
shops = pd.read_csv("./data/shops.csv")
train = pd.read_csv("./data/sales_train.csv")
test = pd.read_csv("./data/test.csv")
item_categories = pd.read_csv('./data/item_categories.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Train
# ###  columns 뜻
#  - data  = 날짜
#  - date_block_num  = 한달 단위로 구분하기 편하게 하기 위한 데이터
#  - shop_id = 가게 id
#  - item_price = 아이템 가격
#  - item_cnt_day = 당일 해당 아이템이 팔린 개수

# %%
train.info() # null 값이 모든데이터에 존재 하지 않는다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
#  date의 자료형을 object  -> dattime 으로 바꾸고 싶다. 
# 변환하는 과정  ->
train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")
train["date"]. head(3)
# Out:
# 0   2013-01-02
# 1   2013-01-03
# 2   2013-01-05
# Name: date, dtype: datetime64[ns]

# %%
train.describe(include = 'all')
# Out:
# <ipython-input-9-90378c3909a9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   train.describe(include = 'all')
#                        date  date_block_num       shop_id       item_id  \
# count               2935849    2.935849e+06  2.935849e+06  2.935849e+06
# unique                 1034             NaN           NaN           NaN
# top     2013-12-28 00:00:00             NaN           NaN           NaN
# freq                   9434             NaN           NaN           NaN
# first   2013-01-01 00:00:00             NaN           NaN           NaN
# last    2015-10-31 00:00:00             NaN           NaN           NaN
# mean                    NaN    1.456991e+01  3.300173e+01  1.019723e+04
# std                     NaN    9.422988e+00  1.622697e+01  6.324297e+03
# min                     NaN    0.000000e+00  0.000000e+00  0.000000e+00
# 25%                     NaN    7.000000e+00  2.200000e+01  4.476000e+03
# 50%                     NaN    1.400000e+01  3.100000e+01  9.343000e+03
# 75%                     NaN    2.300000e+01  4.700000e+01  1.568400e+04
# max                     NaN    3.300000e+01  5.900000e+01  2.216900e+04
#
#           item_price  item_cnt_day
# count   2.935849e+06  2.935849e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    8.908532e+02  1.242641e+00
# std     1.729800e+03  2.618834e+00
# min    -1.000000e+00 -2.200000e+01
# 25%     2.490000e+02  1.000000e+00
# 50%     3.990000e+02  1.000000e+00
# 75%     9.990000e+02  1.000000e+00
# max     3.079800e+05  2.169000e+03

# %% [markdown]
# 2013-01-01 00:00:00 ~ 2015-10-31 00:00:00  까지의 1034일간의 데이터임을 알수있다.
# item_price은 평균과 중위값의 차이가 심한 것으로 보아 이상치가 존재함을 알 수 있디.
# item_cnt_day 는일,이,삼 분위수가 1인데 비해 평균은 대략 1.2  최대값은 2168로 이상치가 존재한다.
# item_cnt_day, item_price에 최소값들은 음수이다.

# %%
def price_item_cnt_day_boxplot():
    plt.figure(figsize = (20,10))
    # item_price 의 박스플롯
    plt.subplot(1,2,1)
    sns.boxplot(x = 'date_block_num' , y= 'item_price',data =train)
    plt.title('item_price')
    plt.grid()
    # item_cnt_day의 박스 플롯
    plt.subplot(1,2,2)
    sns.boxplot(x = 'date_block_num' , y= 'item_cnt_day',data =train)
    plt.title('item_cnt_day')
    plt.grid()
price_item_cnt_day_boxplot()

# %% [markdown]
# - 다음은 date_block_num 별로 item_price의 boxplot이다.
# - 위의 그래프를 기준으로 item_price는 50000 이상 , item_cnt_day 는 1000 이상을 이상치로서 train에서 제거한다.
# - 또한 판매되는 수량을 구하는 것이 목적이므로 0미만의 값을 제거한다.

# %%
condition_for_drop = ((train["item_price"] >= 50000) | (train["item_price"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

condition_for_drop = ((train["item_cnt_day"] >= 1000) | (train["item_cnt_day"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

# %%
# 제거 후의 boxplot
price_item_cnt_day_boxplot()

# %%
train.corr()
# Out:
#                 date_block_num   shop_id   item_id  item_price  item_cnt_day
# date_block_num        1.000000  0.019329  0.009472    0.095539      0.010339
# shop_id               0.019329  1.000000  0.029345   -0.023955     -0.005660
# item_id               0.009472  0.029345  1.000000   -0.134812      0.018896
# item_price            0.095539 -0.023955 -0.134812    1.000000      0.014444
# item_cnt_day          0.010339 -0.005660  0.018896    0.014444      1.000000

# %% [markdown]
# ## shops

# %%
shops.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
shops.head(20)
# Out:
#                          shop_name  shop_id
# 0    !Якутск Орджоникидзе, 56 фран        0
# 1    !Якутск ТЦ "Центральный" фран        1
# 2                 Адыгея ТЦ "Мега"        2
# 3   Балашиха ТРК "Октябрь-Киномир"        3
# 4         Волжский ТЦ "Волга Молл"        4
# 5           Вологда ТРЦ "Мармелад"        5
# 6       Воронеж (Плехановская, 13)        6
# 7           Воронеж ТРЦ "Максимир"        7
# 8     Воронеж ТРЦ Сити-Парк "Град"        8
# 9                Выездная Торговля        9
# 10      Жуковский ул. Чкалова 39м?       10
# 11      Жуковский ул. Чкалова 39м²       11
# 12             Интернет-магазин ЧС       12
# 13             Казань ТЦ "Бехетле"       13
# 14         Казань ТЦ "ПаркХаус" II       14
# 15            Калуга ТРЦ "XXI век"       15
# 16                Коломна ТЦ "Рио"       16
# 17   Красноярск ТЦ "Взлетка Плаза"       17
# 18            Красноярск ТЦ "Июнь"       18
# 19           Курск ТЦ "Пушкинский"       19

# %% [markdown]
# - 이름에 특수문자가 들어가고 중복되는 이름들이 보인다

# %%
def clean_text(inputString):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
    return text_rmv
shops_names = shops["shop_name"].apply(clean_text)
shops_id = shops["shop_id"]
# 중복되는 이름 확인 
for i in list(zip(shops_names ,shops_id)):
    for j in list(zip(shops_names ,shops_id)):
        if (re.match('.*'+i[0]+'*.',j[0])) and (i[1]!= j[1]):
            print('code : ', i[1], ' and  ', j[1])
            print('name : ', i[0], ' and  ', j[0])
# Out:
# code :  10  and   11
# name :  Жуковский ул  Чкалова 39м   and   Жуковский ул  Чкалова 39м²
# code :  11  and   10
# name :  Жуковский ул  Чкалова 39м²  and   Жуковский ул  Чкалова 39м
# code :  39  and   40
# name :  РостовНаДону ТРК  Мегацентр Горизонт   and   РостовНаДону ТРК  Мегацентр Горизонт  Островной
# code :  57  and   0
# name :  Якутск Орджоникидзе  56  and    Якутск Орджоникидзе  56 фран
# code :  58  and   1
# name :  Якутск ТЦ  Центральный   and    Якутск ТЦ  Центральный  фран

# %% [markdown]
# - 위와 같이 shop id가 10:11, 39:40, 57:0, 58:1 4개의 아이디가 중복되는 것을 알 수 있다.
# - 위의 데이터를 기준으로 train data의 shop id를 바꾸어준다

# %%
train["shop_id"] = train["shop_id"].replace({0: 57, 1: 58, 11: 10, 40: 39})

# %% [markdown]
# ## items

# %%
items.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items.head(20) # 이름에 특수 문자 제거 후 비슷한 게임끼리
# Out:
#                                             item_name  item_id  \
# 0           ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1   !ABBYY FineReader 12 Professional Edition Full...        1
# 2       ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3     ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4         ***КОРОБКА (СТЕКЛО)                       D        4
# 5   ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6            ***УДАР ПО ВОРОТАМ (UNI)               D        6
# 7          ***УДАР ПО ВОРОТАМ-2 (UNI)               D        7
# 8            ***ЧАЙ С МУССОЛИНИ                     D        8
# 9       ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D        9
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D       10
# 11          *ЛИНИЯ СМЕРТИ                           D       11
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12
# 13          *СПАСАЯ ЭМИЛИ                           D       13
# 14          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D       14
# 15             //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ (Регион)       15
# 16                         //МОНГОЛ С.Бодров (Регион)       16
# 17                    //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА (Регион)       17
# 18          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D       18
# 19                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72       19
#
#     item_category_id
# 0                 40
# 1                 76
# 2                 40
# 3                 40
# 4                 40
# 5                 40
# 6                 40
# 7                 40
# 8                 40
# 9                 40
# 10                40
# 11                40
# 12                55
# 13                40
# 14                40
# 15                40
# 16                40
# 17                40
# 18                40
# 19                40

# %%
plt.figure(figsize=(20,10))
sns.countplot(x= 'item_category_id' , data = items)
plt.xticks(size = 15 , rotation =  45 , color = 'black')
plt.show()

# %%
item_categories[item_categories['item_category_id']==40]
# Out:
#    item_category_name  item_category_id
# 40         Кино - DVD                40

# %% [markdown]
# - item_category_id =40 인  Кино - DVD 카테고리에 많은 아이템이 존재하는지 알 수 있다

# %% [markdown]
# ## item_category

# %%
item_categories.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories.head(20)
# Out:
#             item_category_name  item_category_id
# 0      PC - Гарнитуры/Наушники                 0
# 1             Аксессуары - PS2                 1
# 2             Аксессуары - PS3                 2
# 3             Аксессуары - PS4                 3
# 4             Аксессуары - PSP                 4
# 5          Аксессуары - PSVita                 5
# 6        Аксессуары - XBOX 360                 6
# 7        Аксессуары - XBOX ONE                 7
# 8               Билеты (Цифра)                 8
# 9              Доставка товара                 9
# 10       Игровые консоли - PS2                10
# 11       Игровые консоли - PS3                11
# 12       Игровые консоли - PS4                12
# 13       Игровые консоли - PSP                13
# 14    Игровые консоли - PSVita                14
# 15  Игровые консоли - XBOX 360                15
# 16  Игровые консоли - XBOX ONE                16
# 17    Игровые консоли - Прочие                17
# 18                  Игры - PS2                18
# 19                  Игры - PS3                19

# %% [markdown]
# - item_category_name에 같은 단어가 들어가는 데이터가 많이 존재한다
# - 이를 묶어 더 큰 범주를 만들 수 있다.

# %% [markdown]
# ## test

# %%
test.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB

# %%
# test의 shop_id , item_id 기 train 데이터에 있는지 확인
diff_test_train_shop_id  = set(test['shop_id']) - set(train['shop_id'])
print('diffrent shop_id nums: ',len(diff_test_train_shop_id))
diff_test_train_item_id = set(test['item_id']) - set(train['item_id'])
print('diffrent item_id nums: ',len(diff_test_train_item_id))
diff_test_items_item_id = set(test['item_id']) - set(items['item_id'])
print('diff_test_items_itemid nums: ',len(diff_test_items_item_id))
# Out:
# diffrent shop_id nums:  0
# diffrent item_id nums:  363
# diff_test_items_itemid nums:  0

# %% [markdown]
# #### test에는 존재하지만 train에 존재하지 않는 값이 363개 존재한다.
# #### items에는 test에 있는 모든 item_id를 가지고 있다.
# #### 이를 해결하기위해 다음과 같은 방법을 사용한다
#  - train에 존재하지 않는 test값을 예측하기 위해 item_category_id를 사용한다.

# %% [markdown]
# ## high_category

# %% [markdown]
# item_category의 앞부분만 자르고 새롭게 만든 열을 라벨인코딩 (악세사리 >> 1)
# item_id와 연결되어있는 item_category를 새롭게 만든 열로 연결하여 test값을 예측한다면?

# %%
# item_category 분류하여 새로운 열 만들기
def make_high_category(data_name_col):
    '''
    상위 분류를 생성후 라벨 인코딩을 하는 함수
    shopname 과 item_category_name 에 사용
    '''
    data_name_col
    data_name_col = data_name_col.apply(clean_text)
    high_category_name = data_name_col.str.split(' ')
    high_category_name = [data[1] if data[0] == '' else data[0] for data in high_category_name]
    high_category_name_le = LabelEncoder()
    high_category_name_le.fit(high_category_name)
    high_category_id = high_category_name_le.transform(high_category_name)
    return high_category_name , high_category_id

# %%
item_categories['high_category_name'] , item_categories['high_category_id'] =\
make_high_category(item_categories.item_category_name)

# %%
item_categories.head(3)
# Out:
#         item_category_name  item_category_id high_category_name  \
# 0  PC - Гарнитуры/Наушники                 0                 PC
# 1         Аксессуары - PS2                 1         Аксессуары
# 2         Аксессуары - PS3                 2         Аксессуары
#
#    high_category_id
# 0                 0
# 1                 1
# 2                 1

# %%
shops['city_name'],shops['city_id'] = make_high_category(shops.shop_name)

# %%
shops.head(3)
# Out:
#                        shop_name  shop_id city_name  city_id
# 0  !Якутск Орджоникидзе, 56 фран        0    Якутск       29
# 1  !Якутск ТЦ "Центральный" фран        1    Якутск       29
# 2               Адыгея ТЦ "Мега"        2    Адыгея        0

# %% [markdown]
# ## train + test

# %%
'''
test에 없는 열을 추가 해야 하거나
train에 쓸모없는 데이터를 제거해야 한다. 
'''
test.columns , train.columns
# Out:
# (Index(['ID', 'shop_id', 'item_id'], dtype='object'),
#  Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#         'item_cnt_day'],
#        dtype='object'))

# %%
test['date_block_num'] = 34
test['item_price'] = 1
test['item_cnt_day'] = 0
del train['date']
del test['ID']

# %%
test.columns , train.columns
# Out:
# (Index(['shop_id', 'item_id', 'date_block_num', 'item_price', 'item_cnt_day'], dtype='object'),
#  Index(['date_block_num', 'shop_id', 'item_id', 'item_price', 'item_cnt_day'], dtype='object'))

# %%
# 인덱스 값이 꼬여있다.
pd.concat([test,train])
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0              5     5037              34         1.0           0.0
# 1              5     5320              34         1.0           0.0
# 2              5     5233              34         1.0           0.0
# 3              5     5232              34         1.0           0.0
# 4              5     5268              34         1.0           0.0
# ...          ...      ...             ...         ...           ...
# 2935844       25     7409              33       299.0           1.0
# 2935845       25     7460              33       299.0           1.0
# 2935846       25     7459              33       349.0           1.0
# 2935847       25     7440              33       299.0           1.0
# 2935848       25     7460              33       299.0           1.0
#
# [3142687 rows x 5 columns]

# %%
pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0             16    18336               0       299.0           1.0
# 1             25    18631               0       149.0           1.0
# 2             25    19333               0       350.0           1.0
# 3             25    19330               0       349.0           1.0
# 4             25    18546               0       149.0           1.0
# ...          ...      ...             ...         ...           ...
# 3142682       57    18454              34         1.0           0.0
# 3142683       57    18027              34         1.0           0.0
# 3142684       57    18049              34         1.0           0.0
# 3142685       57    18589              34         1.0           0.0
# 3142686        5     5037              34         1.0           0.0
#
# [3142687 rows x 5 columns]

# %%
salse_df = pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)

# %%
salse_df = pd.merge(salse_df ,shops ,on =  'shop_id').drop(['shop_name','city_name'] ,axis =1)

# %%
salse_df
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id
# 0             16    18336               0       299.0           1.0       10
# 1             16    21347               0       549.0           1.0       10
# 2             16    20890               0      1899.0           1.0       10
# 3             16    20236               0       299.0           1.0       10
# 4             16    20237               0       299.0           2.0       10
# ...          ...      ...             ...         ...           ...      ...
# 3142682       36     1567              34         1.0           0.0       16
# 3142683       36     1573              34         1.0           0.0       16
# 3142684       36     1574              34         1.0           0.0       16
# 3142685       36     1575              34         1.0           0.0       16
# 3142686       36     4173              34         1.0           0.0       16
#
# [3142687 rows x 6 columns]

# %%
item_high_categories = items.merge(item_categories).drop(['item_name','item_category_name','high_category_name'],axis = 1)
item_high_categories.head(3)
# Out:
#    item_id  item_category_id  high_category_id
# 0        0                40                 7
# 1        2                40                 7
# 2        3                40                 7

# %%
salse_df = pd.merge(salse_df ,item_high_categories ,on =  'item_id')

# %%
salse_df.head(3)
# Out:
#    shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id  \
# 0       16    18336               0       299.0           1.0       10
# 1       25    18336               0       299.0           1.0       13
# 2       25    18336               1       299.0           1.0       13
#
#    item_category_id  high_category_id
# 0                57                 9
# 1                57                 9
# 2                57                 9

# %%
salse_df['item_revenue_days'] = salse_df['item_cnt_day'] * salse_df['item_price']
salse_df
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id  \
# 0             16    18336               0       299.0           1.0       10
# 1             25    18336               0       299.0           1.0       13
# 2             25    18336               1       299.0           1.0       13
# 3             25    18336               7       299.0           1.0       13
# 4             26    18336               2       299.0           1.0       13
# ...          ...      ...             ...         ...           ...      ...
# 3142682       20    21047              33      1899.0           1.0       13
# 3142683       20    21003              33      1899.0           1.0       13
# 3142684       20    21008              33      1899.0           1.0       13
# 3142685       20    21008              33      1899.0           2.0       13
# 3142686       20    21008              33      1899.0           2.0       13
#
#          item_category_id  high_category_id  item_revenue_days
# 0                      57                 9              299.0
# 1                      57                 9              299.0
# 2                      57                 9              299.0
# 3                      57                 9              299.0
# 4                      57                 9              299.0
# ...                   ...               ...                ...
# 3142682                61                10             1899.0
# 3142683                61                10             1899.0
# 3142684                61                10             1899.0
# 3142685                61                10             3798.0
# 3142686                61                10             3798.0
#
# [3142687 rows x 9 columns]

# %%
iccr = salse_df[['item_id','city_id','item_cnt_day','item_revenue_days','date_block_num']]
iccr = iccr.rename(columns={'item_cnt_day':'item_city_cnt_month_mean','item_revenue_days': 'item_city_revenue_month_mean'})

iccr = iccr.pivot_table(index=['date_block_num','item_id','city_id'])
iccr = iccr.reset_index()
iccr = iccr.merge(salse_df)
iccr
# Out:
#          date_block_num  item_id  city_id  item_city_cnt_month_mean  \
# 0                     0       19       13                       1.0
# 1                     0       27        0                       1.0
# 2                     0       27        6                       1.0
# 3                     0       27       12                       1.0
# 4                     0       27       13                       1.0
# ...                 ...      ...      ...                       ...
# 3142682              34    22167       27                       0.0
# 3142683              34    22167       28                       0.0
# 3142684              34    22167       29                       0.0
# 3142685              34    22167       29                       0.0
# 3142686              34    22167       30                       0.0
#
#          item_city_revenue_month_mean  shop_id  item_price  item_cnt_day  \
# 0                                28.0       25        28.0           1.0
# 1                              2499.0        2      2499.0           1.0
# 2                              1890.0       10      1890.0           1.0
# 3                              2499.0       19      2499.0           1.0
# 4                              2499.0       26      2499.0           1.0
# ...                               ...      ...         ...           ...
# 3142682                           0.0       55         1.0           0.0
# 3142683                           0.0       56         1.0           0.0
# 3142684                           0.0       57         1.0           0.0
# 3142685                           0.0       58         1.0           0.0
# 3142686                           0.0       59         1.0           0.0
#
#          item_category_id  high_category_id  item_revenue_days
# 0                      40                 7               28.0
# 1                      19                 5             2499.0
# 2                      19                 5             1890.0
# 3                      19                 5             2499.0
# 4                      19                 5             2499.0
# ...                   ...               ...                ...
# 3142682                49                 8                0.0
# 3142683                49                 8                0.0
# 3142684                49                 8                0.0
# 3142685                49                 8                0.0
# 3142686                49                 8                0.0
#
# [3142687 rows x 11 columns]

# %%
iccr
# item_city = salse_df1.pivot_table(index=['item_id','ty_id'])
# Out:
#          date_block_num  item_id  city_id  item_city_cnt_month_mean  \
# 0                     0       19       13                       1.0
# 1                     0       27        0                       1.0
# 2                     0       27        6                       1.0
# 3                     0       27       12                       1.0
# 4                     0       27       13                       1.0
# ...                 ...      ...      ...                       ...
# 3142682              34    22167       27                       0.0
# 3142683              34    22167       28                       0.0
# 3142684              34    22167       29                       0.0
# 3142685              34    22167       29                       0.0
# 3142686              34    22167       30                       0.0
#
#          item_city_revenue_month_mean  shop_id  item_price  item_cnt_day  \
# 0                                28.0       25        28.0           1.0
# 1                              2499.0        2      2499.0           1.0
# 2                              1890.0       10      1890.0           1.0
# 3                              2499.0       19      2499.0           1.0
# 4                              2499.0       26      2499.0           1.0
# ...                               ...      ...         ...           ...
# 3142682                           0.0       55         1.0           0.0
# 3142683                           0.0       56         1.0           0.0
# 3142684                           0.0       57         1.0           0.0
# 3142685                           0.0       58         1.0           0.0
# 3142686                           0.0       59         1.0           0.0
#
#          item_category_id  high_category_id  item_revenue_days
# 0                      40                 7               28.0
# 1                      19                 5             2499.0
# 2                      19                 5             1890.0
# 3                      19                 5             2499.0
# 4                      19                 5             2499.0
# ...                   ...               ...                ...
# 3142682                49                 8                0.0
# 3142683                49                 8                0.0
# 3142684                49                 8                0.0
# 3142685                49                 8                0.0
# 3142686                49                 8                0.0
#
# [3142687 rows x 11 columns]

# %%
iccr2 = salse_df[['item_id','shop_id','item_cnt_day','item_revenue_days','date_block_num']]
iccr2 = iccr2.rename(columns={'item_cnt_day':'item_shop_cnt_month_mean','item_revenue_days': 'item_shop_revenue_month_mean'})

iccr2 = iccr2.pivot_table(index=['date_block_num','item_id','shop_id'])
iccr2 = iccr2.reset_index()
iccr2 = iccr2.merge(iccr, on=['date_block_num','item_id','shop_id'])
iccr2 = iccr2.drop(['item_id','city_id','shop_id','item_category_id','high_category_id'], axis = 1)
iccr2
# Out:
#          date_block_num  item_shop_cnt_month_mean  \
# 0                     0                       1.0
# 1                     0                       1.0
# 2                     0                       1.0
# 3                     0                       1.0
# 4                     0                       1.0
# ...                 ...                       ...
# 3142682              34                       0.0
# 3142683              34                       0.0
# 3142684              34                       0.0
# 3142685              34                       0.0
# 3142686              34                       0.0
#
#          item_shop_revenue_month_mean  item_city_cnt_month_mean  \
# 0                                28.0                       1.0
# 1                              2499.0                       1.0
# 2                              1890.0                       1.0
# 3                              2499.0                       1.0
# 4                              2499.0                       1.0
# ...                               ...                       ...
# 3142682                           0.0                       0.0
# 3142683                           0.0                       0.0
# 3142684                           0.0                       0.0
# 3142685                           0.0                       0.0
# 3142686                           0.0                       0.0
#
#          item_city_revenue_month_mean  item_price  item_cnt_day  \
# 0                                28.0        28.0           1.0
# 1                              2499.0      2499.0           1.0
# 2                              1890.0      1890.0           1.0
# 3                              2499.0      2499.0           1.0
# 4                              2499.0      2499.0           1.0
# ...                               ...         ...           ...
# 3142682                           0.0         1.0           0.0
# 3142683                           0.0         1.0           0.0
# 3142684                           0.0         1.0           0.0
# 3142685                           0.0         1.0           0.0
# 3142686                           0.0         1.0           0.0
#
#          item_revenue_days
# 0                     28.0
# 1                   2499.0
# 2                   1890.0
# 3                   2499.0
# 4                   2499.0
# ...                    ...
# 3142682                0.0
# 3142683                0.0
# 3142684                0.0
# 3142685                0.0
# 3142686                0.0
#
# [3142687 rows x 8 columns]

# %%
iccr = iccr2

# %% [markdown]
# ## split train , valid , test

# %%
x_train = iccr[iccr['date_block_num'] < 33]
x_train = x_train.drop(['item_cnt_day'], axis = 1)
y_train = iccr[iccr['date_block_num'] < 33]['item_cnt_day']


x_valid = iccr[iccr['date_block_num'] == 33]
x_valid = x_valid.drop(['item_cnt_day'], axis = 1)
y_valid = iccr[iccr['date_block_num'] == 33]['item_cnt_day']

x_test = iccr[iccr['date_block_num'] == 34]
x_test = x_test.drop(['item_cnt_day'], axis = 1)
y_test = iccr[iccr['date_block_num'] == 34]['item_cnt_day']

# %%
x_train
# Out:
#          date_block_num  item_shop_cnt_month_mean  \
# 0                     0                  1.000000
# 1                     0                  1.000000
# 2                     0                  1.000000
# 3                     0                  1.000000
# 4                     0                  1.000000
# ...                 ...                       ...
# 2875097              32                  1.000000
# 2875098              32                  1.000000
# 2875099              32                  1.333333
# 2875100              32                  1.333333
# 2875101              32                  1.333333
#
#          item_shop_revenue_month_mean  item_city_cnt_month_mean  \
# 0                           28.000000                  1.000000
# 1                         2499.000000                  1.000000
# 2                         1890.000000                  1.000000
# 3                         2499.000000                  1.000000
# 4                         2499.000000                  1.000000
# ...                               ...                       ...
# 2875097                    299.000000                  1.000000
# 2875098                    299.000000                  1.000000
# 2875099                    398.666667                  1.333333
# 2875100                    398.666667                  1.333333
# 2875101                    398.666667                  1.333333
#
#          item_city_revenue_month_mean  item_price  item_revenue_days
# 0                           28.000000        28.0               28.0
# 1                         2499.000000      2499.0             2499.0
# 2                         1890.000000      1890.0             1890.0
# 3                         2499.000000      2499.0             2499.0
# 4                         2499.000000      2499.0             2499.0
# ...                               ...         ...                ...
# 2875097                    299.000000       299.0              299.0
# 2875098                    299.000000       299.0              299.0
# 2875099                    398.666667       299.0              299.0
# 2875100                    398.666667       299.0              299.0
# 2875101                    398.666667       299.0              598.0
#
# [2875102 rows x 7 columns]

# %% [markdown]
# ## PCA

# %% [markdown]
# 독립변인은 다른 변인에 영향을 주는 변인을 말하며,
# 종속변인은 영향을 받거나 의존하는 변인,
# 즉 독립변인에 의해 변화되는 변인을 말한다.
# 이때 독립변인이 종속변인에 미치는 영향의 효과가
# 다른 변인의 수준에 의해 달라지면 이 변인을 조절변인이라 한다.

# %%
from sklearn.preprocessing import Stand
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-dd490da28dc4> in <module>
# ----> 1 scaler = StandardScaler()
#       2 scaler.fit(x_train)
#
# NameError: name 'StandardScaler' is not defined

# %%
scaled_data = scaler.transform(x_train)
scaled_data

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(scaled_data)

# %%
x_pca=pca.transform(scaled_data)
pca.explained_variance_

# %%
pca.components_

# %%
x_pca.shape

# %%
x_pca

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:0],x_pca[:1], c=x_train['item_category_id_x'])
plt.xlabel('xzxc')
plt.ylabel('zxc')
plt.show()

# %% [markdown]
# ## 표준화? 정규화?

# %%
from sklearn.preprocessing import StandardScaler  # 표준화 패키지 라이브러리 
x = x_train.drop(['date_block_num'], axis=1).values # 독립변인들의 value값만 추출
y = x_train['item_price'].values # 종속변인 추출

x = StandardScaler().fit_transform(x) # x객체에 x를 표준화한 데이터를 저장

features = ['date_block_num']
pd.DataFrame([x], columns=features).head()

# %% [markdown]
# ## PCA 실행 ? 차원축소?

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2) # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data=printcipalComponents, columns = ['principal component1', 'principal component2'])
# 주성분으로 이루어진 데이터 프레임 구성

# %% [markdown]
# ## XGboost

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    x_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set= [(x_valid, y_valid)], 
    verbose=True, 
    early_stopping_rounds = 150)
# Out:
# C:\Users\songsangmin\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\songsangmin\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:2.62456
# [1]	validation_0-rmse:2.41014
# [2]	validation_0-rmse:2.23688
# [3]	validation_0-rmse:2.12881
# [4]	validation_0-rmse:2.05511
# [5]	validation_0-rmse:2.01759
# [6]	validation_0-rmse:1.99370
# [7]	validation_0-rmse:1.99396
# [8]	validation_0-rmse:1.96117
# [9]	validation_0-rmse:1.93644
# [10]	validation_0-rmse:1.94277
# [11]	validation_0-rmse:1.94703
# [12]	validation_0-rmse:1.92562
# [13]	validation_0-rmse:1.91487
# [14]	validation_0-rmse:1.92349
# [15]	validation_0-rmse:1.92941
# [16]	validation_0-rmse:1.92401
# [17]	validation_0-rmse:1.91198
# [18]	validation_0-rmse:1.92227
# [19]	validation_0-rmse:1.91300
# [20]	validation_0-rmse:1.92329
# [21]	validation_0-rmse:1.92051
# [22]	validation_0-rmse:1.92005
# [23]	validation_0-rmse:1.92821
# [24]	validation_0-rmse:1.92034
# [25]	validation_0-rmse:1.92959
# [26]	validation_0-rmse:1.92692
# [27]	validation_0-rmse:1.92223
# [28]	validation_0-rmse:1.91544
# [29]	validation_0-rmse:1.92418
# [30]	validation_0-rmse:1.91436
# [31]	validation_0-rmse:1.90928
# [32]	validation_0-rmse:1.92084
# [33]	validation_0-rmse:1.91592
# [34]	validation_0-rmse:1.90772
# [35]	validation_0-rmse:1.91438
# [36]	validation_0-rmse:1.92481
# [37]	validation_0-rmse:1.91665
# [38]	validation_0-rmse:1.92628
# [39]	validation_0-rmse:1.91866
# [40]	validation_0-rmse:1.92588
# [41]	validation_0-rmse:1.92663
# [42]	validation_0-rmse:1.92344
# [43]	validation_0-rmse:1.91836
# [44]	validation_0-rmse:1.92328
# [45]	validation_0-rmse:1.93092
# [46]	validation_0-rmse:1.92781
# [47]	validation_0-rmse:1.92456
# [48]	validation_0-rmse:1.92173
# [49]	validation_0-rmse:1.91926
# [50]	validation_0-rmse:1.92613
# [51]	validation_0-rmse:1.91856
# [52]	validation_0-rmse:1.92508
# [53]	validation_0-rmse:1.91890
# [54]	validation_0-rmse:1.92497
# [55]	validation_0-rmse:1.91818
# [56]	validation_0-rmse:1.91316
# [57]	validation_0-rmse:1.92132
# [58]	validation_0-rmse:1.91508
# [59]	validation_0-rmse:1.91380
# [60]	validation_0-rmse:1.92120
# [61]	validation_0-rmse:1.92889
# [62]	validation_0-rmse:1.93012
# [63]	validation_0-rmse:1.92387
# [64]	validation_0-rmse:1.91815
# [65]	validation_0-rmse:1.91578
# [66]	validation_0-rmse:1.91247
# [67]	validation_0-rmse:1.91688
# [68]	validation_0-rmse:1.91442
# [69]	validation_0-rmse:1.92115
# [70]	validation_0-rmse:1.91550
# [71]	validation_0-rmse:1.91214
# [72]	validation_0-rmse:1.91379
# [73]	validation_0-rmse:1.91198
# [74]	validation_0-rmse:1.91864
# [75]	validation_0-rmse:1.91274
# [76]	validation_0-rmse:1.91885
# [77]	validation_0-rmse:1.91569
# [78]	validation_0-rmse:1.92150
# [79]	validation_0-rmse:1.92547
# [80]	validation_0-rmse:1.92165
# [81]	validation_0-rmse:1.91663
# [82]	validation_0-rmse:1.90423
# [83]	validation_0-rmse:1.90033
# [84]	validation_0-rmse:1.89602
# [85]	validation_0-rmse:1.88937
# [86]	validation_0-rmse:1.88537
# [87]	validation_0-rmse:1.88990
# [88]	validation_0-rmse:1.88657
# [89]	validation_0-rmse:1.88272
# [90]	validation_0-rmse:1.88698
# [91]	validation_0-rmse:1.89243
# [92]	validation_0-rmse:1.88561
# [93]	validation_0-rmse:1.88445
# [94]	validation_0-rmse:1.88841
# [95]	validation_0-rmse:1.89190
# [96]	validation_0-rmse:1.88850
# [97]	validation_0-rmse:1.88508
# [98]	validation_0-rmse:1.88284
# [99]	validation_0-rmse:1.87887
# [100]	validation_0-rmse:1.87567
# [101]	validation_0-rmse:1.88022
# [102]	validation_0-rmse:1.87880
# [103]	validation_0-rmse:1.87532
# [104]	validation_0-rmse:1.87794
# [105]	validation_0-rmse:1.88377
# [106]	validation_0-rmse:1.88751
# [107]	validation_0-rmse:1.88355
# [108]	validation_0-rmse:1.88011
# [109]	validation_0-rmse:1.87611
# [110]	validation_0-rmse:1.88205
# [111]	validation_0-rmse:1.88126
# [112]	validation_0-rmse:1.87668
# [113]	validation_0-rmse:1.87963
# [114]	validation_0-rmse:1.87841
# [115]	validation_0-rmse:1.88050
# [116]	validation_0-rmse:1.87761
# [117]	validation_0-rmse:1.87931
# [118]	validation_0-rmse:1.87560
# [119]	validation_0-rmse:1.87743
# [120]	validation_0-rmse:1.88067
# [121]	validation_0-rmse:1.87802
# [122]	validation_0-rmse:1.87635
# [123]	validation_0-rmse:1.88093
# [124]	validation_0-rmse:1.87399
# [125]	validation_0-rmse:1.87482
# [126]	validation_0-rmse:1.87860
# [127]	validation_0-rmse:1.88092
# [128]	validation_0-rmse:1.87915
# [129]	validation_0-rmse:1.88059
# [130]	validation_0-rmse:1.87495
# [131]	validation_0-rmse:1.87399
# [132]	validation_0-rmse:1.87631
# [133]	validation_0-rmse:1.87850
# [134]	validation_0-rmse:1.87394
# [135]	validation_0-rmse:1.87499
# [136]	validation_0-rmse:1.87740
# [137]	validation_0-rmse:1.87579
# [138]	validation_0-rmse:1.87233
# [139]	validation_0-rmse:1.87507
# [140]	validation_0-rmse:1.87229
# [141]	validation_0-rmse:1.87037
# [142]	validation_0-rmse:1.87145
# [143]	validation_0-rmse:1.87378
# [144]	validation_0-rmse:1.87453
# [145]	validation_0-rmse:1.87272
# [146]	validation_0-rmse:1.87552
# [147]	validation_0-rmse:1.87479
# [148]	validation_0-rmse:1.87824
# [149]	validation_0-rmse:1.87339
# [150]	validation_0-rmse:1.87188
# [151]	validation_0-rmse:1.86871
# [152]	validation_0-rmse:1.87195
# [153]	validation_0-rmse:1.87196
# [154]	validation_0-rmse:1.86621
# [155]	validation_0-rmse:1.87021
# [156]	validation_0-rmse:1.87290
# [157]	validation_0-rmse:1.87465
# [158]	validation_0-rmse:1.86947
# [159]	validation_0-rmse:1.86687
# [160]	validation_0-rmse:1.87019
# [161]	validation_0-rmse:1.86759
# [162]	validation_0-rmse:1.86934
# [163]	validation_0-rmse:1.87102
# [164]	validation_0-rmse:1.87204
# [165]	validation_0-rmse:1.87444
# [166]	validation_0-rmse:1.87322
# [167]	validation_0-rmse:1.87194
# [168]	validation_0-rmse:1.87254
# [169]	validation_0-rmse:1.87510
# [170]	validation_0-rmse:1.87249
# [171]	validation_0-rmse:1.86791
# [172]	validation_0-rmse:1.86961
# [173]	validation_0-rmse:1.87004
# [174]	validation_0-rmse:1.86750
# [175]	validation_0-rmse:1.87089
# [176]	validation_0-rmse:1.86887
# [177]	validation_0-rmse:1.86679
# [178]	validation_0-rmse:1.86591
# [179]	validation_0-rmse:1.86899
# [180]	validation_0-rmse:1.86650
# [181]	validation_0-rmse:1.86464
# [182]	validation_0-rmse:1.86246
# [183]	validation_0-rmse:1.85878
# [184]	validation_0-rmse:1.86230
# [185]	validation_0-rmse:1.85910
# [186]	validation_0-rmse:1.85730
# [187]	validation_0-rmse:1.85957
# [188]	validation_0-rmse:1.85738
# [189]	validation_0-rmse:1.85542
# [190]	validation_0-rmse:1.85758
# [191]	validation_0-rmse:1.85638
# [192]	validation_0-rmse:1.85634
# [193]	validation_0-rmse:1.85904
# [194]	validation_0-rmse:1.86009
# [195]	validation_0-rmse:1.86170
# [196]	validation_0-rmse:1.85719
# [197]	validation_0-rmse:1.85456
# [198]	validation_0-rmse:1.85254
# [199]	validation_0-rmse:1.85104
# [200]	validation_0-rmse:1.85525
# [201]	validation_0-rmse:1.84830
# [202]	validation_0-rmse:1.84951
# [203]	validation_0-rmse:1.85122
# [204]	validation_0-rmse:1.85190
# [205]	validation_0-rmse:1.84996
# [206]	validation_0-rmse:1.85200
# [207]	validation_0-rmse:1.85322
# [208]	validation_0-rmse:1.85450
# [209]	validation_0-rmse:1.85176
# [210]	validation_0-rmse:1.85001
# [211]	validation_0-rmse:1.85416
# [212]	validation_0-rmse:1.84596
# [213]	validation_0-rmse:1.84760
# [214]	validation_0-rmse:1.84066
# [215]	validation_0-rmse:1.84203
# [216]	validation_0-rmse:1.83673
# [217]	validation_0-rmse:1.83794
# [218]	validation_0-rmse:1.83584
# [219]	validation_0-rmse:1.83382
# [220]	validation_0-rmse:1.83604
# [221]	validation_0-rmse:1.83282
# [222]	validation_0-rmse:1.83674
# [223]	validation_0-rmse:1.83478
# [224]	validation_0-rmse:1.83324
# [225]	validation_0-rmse:1.83735
# [226]	validation_0-rmse:1.83412
# [227]	validation_0-rmse:1.83274
# [228]	validation_0-rmse:1.83094
# [229]	validation_0-rmse:1.82907
# [230]	validation_0-rmse:1.82905
# [231]	validation_0-rmse:1.83152
# [232]	validation_0-rmse:1.82873
# [233]	validation_0-rmse:1.83267
# [234]	validation_0-rmse:1.83404
# [235]	validation_0-rmse:1.83107
# [236]	validation_0-rmse:1.82951
# [237]	validation_0-rmse:1.83124
# [238]	validation_0-rmse:1.83271
# [239]	validation_0-rmse:1.83617
# [240]	validation_0-rmse:1.83453
# [241]	validation_0-rmse:1.83321
# [242]	validation_0-rmse:1.83446
# [243]	validation_0-rmse:1.83360
# [244]	validation_0-rmse:1.83242
# [245]	validation_0-rmse:1.83585
# [246]	validation_0-rmse:1.83809
# [247]	validation_0-rmse:1.83493
# [248]	validation_0-rmse:1.83216
# [249]	validation_0-rmse:1.82935
# [250]	validation_0-rmse:1.83242
# [251]	validation_0-rmse:1.83407
# [252]	validation_0-rmse:1.83517
# [253]	validation_0-rmse:1.83133
# [254]	validation_0-rmse:1.83411
# [255]	validation_0-rmse:1.83156
# [256]	validation_0-rmse:1.82794
# [257]	validation_0-rmse:1.82597
# [258]	validation_0-rmse:1.82486
# [259]	validation_0-rmse:1.82650
# [260]	validation_0-rmse:1.82767
# [261]	validation_0-rmse:1.82962
# [262]	validation_0-rmse:1.83248
# [263]	validation_0-rmse:1.83087
# [264]	validation_0-rmse:1.82998
# [265]	validation_0-rmse:1.83238
# [266]	validation_0-rmse:1.83054
# [267]	validation_0-rmse:1.83817
# [268]	validation_0-rmse:1.83332
# [269]	validation_0-rmse:1.83497
# [270]	validation_0-rmse:1.83217
# [271]	validation_0-rmse:1.83321
# [272]	validation_0-rmse:1.83522
# [273]	validation_0-rmse:1.83390
# [274]	validation_0-rmse:1.83042
# [275]	validation_0-rmse:1.83250
# [276]	validation_0-rmse:1.83143
# [277]	validation_0-rmse:1.82922
# [278]	validation_0-rmse:1.83156
# [279]	validation_0-rmse:1.82905
# [280]	validation_0-rmse:1.82763
# [281]	validation_0-rmse:1.82505
# [282]	validation_0-rmse:1.82600
# [283]	validation_0-rmse:1.83020
# [284]	validation_0-rmse:1.82792
# [285]	validation_0-rmse:1.83139
# [286]	validation_0-rmse:1.82955
# [287]	validation_0-rmse:1.83100
# [288]	validation_0-rmse:1.82700
# [289]	validation_0-rmse:1.82951
# [290]	validation_0-rmse:1.82910
# [291]	validation_0-rmse:1.83161
# [292]	validation_0-rmse:1.83010
# [293]	validation_0-rmse:1.82729
# [294]	validation_0-rmse:1.82483
# [295]	validation_0-rmse:1.82150
# [296]	validation_0-rmse:1.81826
# [297]	validation_0-rmse:1.81625
# [298]	validation_0-rmse:1.81581
# [299]	validation_0-rmse:1.81777
# [300]	validation_0-rmse:1.82001
# [301]	validation_0-rmse:1.82326
# [302]	validation_0-rmse:1.82129
# [303]	validation_0-rmse:1.81894
# [304]	validation_0-rmse:1.81588
# [305]	validation_0-rmse:1.81902
# [306]	validation_0-rmse:1.82034
# [307]	validation_0-rmse:1.82114
# [308]	validation_0-rmse:1.82041
# [309]	validation_0-rmse:1.81927
# [310]	validation_0-rmse:1.81748
# [311]	validation_0-rmse:1.82015
# [312]	validation_0-rmse:1.82187
# [313]	validation_0-rmse:1.82089
# [314]	validation_0-rmse:1.82167
# [315]	validation_0-rmse:1.82077
# [316]	validation_0-rmse:1.81872
# [317]	validation_0-rmse:1.81652
# [318]	validation_0-rmse:1.80751
# [319]	validation_0-rmse:1.80518
# [320]	validation_0-rmse:1.80667
# [321]	validation_0-rmse:1.80364
# [322]	validation_0-rmse:1.80014
# [323]	validation_0-rmse:1.79881
# [324]	validation_0-rmse:1.80310
# [325]	validation_0-rmse:1.80290
# [326]	validation_0-rmse:1.80059
# [327]	validation_0-rmse:1.79962
# [328]	validation_0-rmse:1.79771
# [329]	validation_0-rmse:1.79898
# [330]	validation_0-rmse:1.80115
# [331]	validation_0-rmse:1.79592
# [332]	validation_0-rmse:1.80157
# [333]	validation_0-rmse:1.80438
# [334]	validation_0-rmse:1.80319
# [335]	validation_0-rmse:1.80508
# [336]	validation_0-rmse:1.80314
# [337]	validation_0-rmse:1.80218
# [338]	validation_0-rmse:1.80054
# [339]	validation_0-rmse:1.80376
# [340]	validation_0-rmse:1.80468
# [341]	validation_0-rmse:1.80255
# [342]	validation_0-rmse:1.80411
# [343]	validation_0-rmse:1.80195
# [344]	validation_0-rmse:1.80436
# [345]	validation_0-rmse:1.80275
# [346]	validation_0-rmse:1.80080
# [347]	validation_0-rmse:1.79953
# [348]	validation_0-rmse:1.80194
# [349]	validation_0-rmse:1.79836
# [350]	validation_0-rmse:1.79768
# [351]	validation_0-rmse:1.79689
# [352]	validation_0-rmse:1.80020
# [353]	validation_0-rmse:1.79821
# [354]	validation_0-rmse:1.79748
# [355]	validation_0-rmse:1.79975
# [356]	validation_0-rmse:1.79799
# [357]	validation_0-rmse:1.79232
# [358]	validation_0-rmse:1.79072
# [359]	validation_0-rmse:1.79512
# [360]	validation_0-rmse:1.79707
# [361]	validation_0-rmse:1.79387
# [362]	validation_0-rmse:1.79712
# [363]	validation_0-rmse:1.79540
# [364]	validation_0-rmse:1.79718
# [365]	validation_0-rmse:1.79552
# [366]	validation_0-rmse:1.79678
# [367]	validation_0-rmse:1.79948
# [368]	validation_0-rmse:1.80270
# [369]	validation_0-rmse:1.79993
# [370]	validation_0-rmse:1.79691
# [371]	validation_0-rmse:1.80190
# [372]	validation_0-rmse:1.79727
# [373]	validation_0-rmse:1.79508
# [374]	validation_0-rmse:1.79023
# [375]	validation_0-rmse:1.78790
# [376]	validation_0-rmse:1.79115
# [377]	validation_0-rmse:1.78933
# [378]	validation_0-rmse:1.78783
# [379]	validation_0-rmse:1.78535
# [380]	validation_0-rmse:1.78318
# [381]	validation_0-rmse:1.78185
# [382]	validation_0-rmse:1.78438
# [383]	validation_0-rmse:1.78617
# [384]	validation_0-rmse:1.78412
# [385]	validation_0-rmse:1.78114
# [386]	validation_0-rmse:1.78388
# [387]	validation_0-rmse:1.78269
# [388]	validation_0-rmse:1.78085
# [389]	validation_0-rmse:1.77792
# [390]	validation_0-rmse:1.78218
# [391]	validation_0-rmse:1.78152
# [392]	validation_0-rmse:1.78472
# [393]	validation_0-rmse:1.78146
# [394]	validation_0-rmse:1.78605
# [395]	validation_0-rmse:1.78987
# [396]	validation_0-rmse:1.79184
# [397]	validation_0-rmse:1.78638
# [398]	validation_0-rmse:1.78420
# [399]	validation_0-rmse:1.79060
# [400]	validation_0-rmse:1.78760
# [401]	validation_0-rmse:1.78568
# [402]	validation_0-rmse:1.78927
# [403]	validation_0-rmse:1.78664
# [404]	validation_0-rmse:1.78332
# [405]	validation_0-rmse:1.78129
# [406]	validation_0-rmse:1.78215
# [407]	validation_0-rmse:1.78095
# [408]	validation_0-rmse:1.77859
# [409]	validation_0-rmse:1.77700
# [410]	validation_0-rmse:1.78151
# [411]	validation_0-rmse:1.78067
# [412]	validation_0-rmse:1.77746
# [413]	validation_0-rmse:1.77559
# [414]	validation_0-rmse:1.77663
# [415]	validation_0-rmse:1.77355
# [416]	validation_0-rmse:1.77281
# [417]	validation_0-rmse:1.77490
# [418]	validation_0-rmse:1.77907
# [419]	validation_0-rmse:1.78080
# [420]	validation_0-rmse:1.77868
# [421]	validation_0-rmse:1.77684
# [422]	validation_0-rmse:1.77872
# [423]	validation_0-rmse:1.77942
# [424]	validation_0-rmse:1.77427
# [425]	validation_0-rmse:1.77785
# [426]	validation_0-rmse:1.78071
# [427]	validation_0-rmse:1.77838
# [428]	validation_0-rmse:1.77997
# [429]	validation_0-rmse:1.77872
# [430]	validation_0-rmse:1.78071
# [431]	validation_0-rmse:1.77949
# [432]	validation_0-rmse:1.77686
# [433]	validation_0-rmse:1.78210
# [434]	validation_0-rmse:1.78457
# [435]	validation_0-rmse:1.78287
# [436]	validation_0-rmse:1.78488
# [437]	validation_0-rmse:1.78666
# [438]	validation_0-rmse:1.78352
# [439]	validation_0-rmse:1.78257
# [440]	validation_0-rmse:1.78649
# [441]	validation_0-rmse:1.78554
# [442]	validation_0-rmse:1.78638
# [443]	validation_0-rmse:1.78182
# [444]	validation_0-rmse:1.77888
# [445]	validation_0-rmse:1.78069
# [446]	validation_0-rmse:1.78403
# [447]	validation_0-rmse:1.78644
# [448]	validation_0-rmse:1.78718
# [449]	validation_0-rmse:1.78464
# [450]	validation_0-rmse:1.78341
# [451]	validation_0-rmse:1.78402
# [452]	validation_0-rmse:1.78699
# [453]	validation_0-rmse:1.78824
# [454]	validation_0-rmse:1.78712
# [455]	validation_0-rmse:1.78782
# [456]	validation_0-rmse:1.79057
# [457]	validation_0-rmse:1.78803
# [458]	validation_0-rmse:1.79038
# [459]	validation_0-rmse:1.79238
# [460]	validation_0-rmse:1.79041
# [461]	validation_0-rmse:1.78885
# [462]	validation_0-rmse:1.78471
# [463]	validation_0-rmse:1.78223
# [464]	validation_0-rmse:1.78296
# [465]	validation_0-rmse:1.78202
# [466]	validation_0-rmse:1.78274
# [467]	validation_0-rmse:1.78252
# [468]	validation_0-rmse:1.78527
# [469]	validation_0-rmse:1.78257
# [470]	validation_0-rmse:1.78504
# [471]	validation_0-rmse:1.78362
# [472]	validation_0-rmse:1.78307
# [473]	validation_0-rmse:1.78048
# [474]	validation_0-rmse:1.78233
# [475]	validation_0-rmse:1.77802
# [476]	validation_0-rmse:1.78198
# [477]	validation_0-rmse:1.78470
# [478]	validation_0-rmse:1.78664
# [479]	validation_0-rmse:1.78307
# [480]	validation_0-rmse:1.77971
# [481]	validation_0-rmse:1.78233
# [482]	validation_0-rmse:1.78120
# [483]	validation_0-rmse:1.78232
# [484]	validation_0-rmse:1.77999
# [485]	validation_0-rmse:1.77864
# [486]	validation_0-rmse:1.78016
# [487]	validation_0-rmse:1.77885
# [488]	validation_0-rmse:1.78147
# [489]	validation_0-rmse:1.78304
# [490]	validation_0-rmse:1.77993
# [491]	validation_0-rmse:1.77995
# [492]	validation_0-rmse:1.78307
# [493]	validation_0-rmse:1.78114
# [494]	validation_0-rmse:1.78116
# [495]	validation_0-rmse:1.77837
# [496]	validation_0-rmse:1.78175
# [497]	validation_0-rmse:1.77904
# [498]	validation_0-rmse:1.77997
# [499]	validation_0-rmse:1.77918
# [500]	validation_0-rmse:1.77836
# [501]	validation_0-rmse:1.77652
# [502]	validation_0-rmse:1.77682
# [503]	validation_0-rmse:1.77378
# [504]	validation_0-rmse:1.77876
# [505]	validation_0-rmse:1.77661
# [506]	validation_0-rmse:1.77853
# [507]	validation_0-rmse:1.77707
# [508]	validation_0-rmse:1.77889
# [509]	validation_0-rmse:1.77773
# [510]	validation_0-rmse:1.77829
# [511]	validation_0-rmse:1.77685
# [512]	validation_0-rmse:1.77493
# [513]	validation_0-rmse:1.77877
# [514]	validation_0-rmse:1.77587
# [515]	validation_0-rmse:1.77460
# [516]	validation_0-rmse:1.77061
# [517]	validation_0-rmse:1.76903
# [518]	validation_0-rmse:1.77278
# [519]	validation_0-rmse:1.77433
# [520]	validation_0-rmse:1.77753
# [521]	validation_0-rmse:1.77533
# [522]	validation_0-rmse:1.77664
# [523]	validation_0-rmse:1.77803
# [524]	validation_0-rmse:1.77571
# [525]	validation_0-rmse:1.77368
# [526]	validation_0-rmse:1.77568
# [527]	validation_0-rmse:1.77471
# [528]	validation_0-rmse:1.77674
# [529]	validation_0-rmse:1.77385
# [530]	validation_0-rmse:1.77660
# [531]	validation_0-rmse:1.77943
# [532]	validation_0-rmse:1.78131
# [533]	validation_0-rmse:1.78281
# [534]	validation_0-rmse:1.78128
# [535]	validation_0-rmse:1.77893
# [536]	validation_0-rmse:1.77993
# [537]	validation_0-rmse:1.77844
# [538]	validation_0-rmse:1.77974
# [539]	validation_0-rmse:1.78175
# [540]	validation_0-rmse:1.77820
# [541]	validation_0-rmse:1.77667
# [542]	validation_0-rmse:1.77584
# [543]	validation_0-rmse:1.77950
# [544]	validation_0-rmse:1.77758
# [545]	validation_0-rmse:1.78007
# [546]	validation_0-rmse:1.78300
# [547]	validation_0-rmse:1.78120
# [548]	validation_0-rmse:1.77891
# [549]	validation_0-rmse:1.77615
# [550]	validation_0-rmse:1.77719
# [551]	validation_0-rmse:1.77978
# [552]	validation_0-rmse:1.77706
# [553]	validation_0-rmse:1.78050
# [554]	validation_0-rmse:1.77698
# [555]	validation_0-rmse:1.77840
# [556]	validation_0-rmse:1.77576
# [557]	validation_0-rmse:1.77786
# [558]	validation_0-rmse:1.78223
# [559]	validation_0-rmse:1.77966
# [560]	validation_0-rmse:1.78105
# [561]	validation_0-rmse:1.78399
# [562]	validation_0-rmse:1.78157
# [563]	validation_0-rmse:1.78388
# [564]	validation_0-rmse:1.78134
# [565]	validation_0-rmse:1.77931
# [566]	validation_0-rmse:1.77748
# [567]	validation_0-rmse:1.77840
# [568]	validation_0-rmse:1.78004
# [569]	validation_0-rmse:1.77609
# [570]	validation_0-rmse:1.77517
# [571]	validation_0-rmse:1.77719
# [572]	validation_0-rmse:1.77968
# [573]	validation_0-rmse:1.77653
# [574]	validation_0-rmse:1.77731
# [575]	validation_0-rmse:1.78001
# [576]	validation_0-rmse:1.78131
# [577]	validation_0-rmse:1.77901
# [578]	validation_0-rmse:1.77679
# [579]	validation_0-rmse:1.78031
# [580]	validation_0-rmse:1.77745
# [581]	validation_0-rmse:1.77601
# [582]	validation_0-rmse:1.77738
# [583]	validation_0-rmse:1.77843
# [584]	validation_0-rmse:1.77822
# [585]	validation_0-rmse:1.77655
# [586]	validation_0-rmse:1.77529
# [587]	validation_0-rmse:1.77693
# [588]	validation_0-rmse:1.77451
# [589]	validation_0-rmse:1.77229
# [590]	validation_0-rmse:1.77088
# [591]	validation_0-rmse:1.76992
# [592]	validation_0-rmse:1.77079
# [593]	validation_0-rmse:1.77027
# [594]	validation_0-rmse:1.77156
# [595]	validation_0-rmse:1.77582
# [596]	validation_0-rmse:1.77446
# [597]	validation_0-rmse:1.77277
# [598]	validation_0-rmse:1.77583
# [599]	validation_0-rmse:1.77358
# [600]	validation_0-rmse:1.77133
# [601]	validation_0-rmse:1.76920
# [602]	validation_0-rmse:1.77082
# [603]	validation_0-rmse:1.76980
# [604]	validation_0-rmse:1.77337
# [605]	validation_0-rmse:1.77545
# [606]	validation_0-rmse:1.77323
# [607]	validation_0-rmse:1.76832
# [608]	validation_0-rmse:1.76594
# [609]	validation_0-rmse:1.76529
# [610]	validation_0-rmse:1.76694
# [611]	validation_0-rmse:1.76556
# [612]	validation_0-rmse:1.76936
# [613]	validation_0-rmse:1.77469
# [614]	validation_0-rmse:1.77462
# [615]	validation_0-rmse:1.77297
# [616]	validation_0-rmse:1.77365
# [617]	validation_0-rmse:1.77182
# [618]	validation_0-rmse:1.77047
# [619]	validation_0-rmse:1.76813
# [620]	validation_0-rmse:1.76935
# [621]	validation_0-rmse:1.76811
# [622]	validation_0-rmse:1.76678
# [623]	validation_0-rmse:1.76553
# [624]	validation_0-rmse:1.76570
# [625]	validation_0-rmse:1.77012
# [626]	validation_0-rmse:1.76646
# [627]	validation_0-rmse:1.76495
# [628]	validation_0-rmse:1.76234
# [629]	validation_0-rmse:1.76260
# [630]	validation_0-rmse:1.76393
# [631]	validation_0-rmse:1.76139
# [632]	validation_0-rmse:1.75900
# [633]	validation_0-rmse:1.76130
# [634]	validation_0-rmse:1.76569
# [635]	validation_0-rmse:1.76236
# [636]	validation_0-rmse:1.75993
# [637]	validation_0-rmse:1.76271
# [638]	validation_0-rmse:1.76357
# [639]	validation_0-rmse:1.76432
# [640]	validation_0-rmse:1.76383
# [641]	validation_0-rmse:1.76329
# [642]	validation_0-rmse:1.76176
# [643]	validation_0-rmse:1.75789
# [644]	validation_0-rmse:1.75936
# [645]	validation_0-rmse:1.75974
# [646]	validation_0-rmse:1.76077
# [647]	validation_0-rmse:1.75932
# [648]	validation_0-rmse:1.75810
# [649]	validation_0-rmse:1.76005
# [650]	validation_0-rmse:1.75902
# [651]	validation_0-rmse:1.76165
# [652]	validation_0-rmse:1.76065
# [653]	validation_0-rmse:1.75936
# [654]	validation_0-rmse:1.76123
# [655]	validation_0-rmse:1.76020
# [656]	validation_0-rmse:1.75679
# [657]	validation_0-rmse:1.76225
# [658]	validation_0-rmse:1.76547
# [659]	validation_0-rmse:1.76571
# [660]	validation_0-rmse:1.76493
# [661]	validation_0-rmse:1.76724
# [662]	validation_0-rmse:1.76647
# [663]	validation_0-rmse:1.76599
# [664]	validation_0-rmse:1.76276
# [665]	validation_0-rmse:1.76115
# [666]	validation_0-rmse:1.75800
# [667]	validation_0-rmse:1.75920
# [668]	validation_0-rmse:1.75708
# [669]	validation_0-rmse:1.75521
# [670]	validation_0-rmse:1.75521
# [671]	validation_0-rmse:1.75791
# [672]	validation_0-rmse:1.75652
# [673]	validation_0-rmse:1.75522
# [674]	validation_0-rmse:1.75378
# [675]	validation_0-rmse:1.75215
# [676]	validation_0-rmse:1.75340
# [677]	validation_0-rmse:1.75698
# [678]	validation_0-rmse:1.75837
# [679]	validation_0-rmse:1.76093
# [680]	validation_0-rmse:1.76218
# [681]	validation_0-rmse:1.76083
# [682]	validation_0-rmse:1.75876
# [683]	validation_0-rmse:1.76018
# [684]	validation_0-rmse:1.76223
# [685]	validation_0-rmse:1.75933
# [686]	validation_0-rmse:1.75574
# [687]	validation_0-rmse:1.75692
# [688]	validation_0-rmse:1.75452
# [689]	validation_0-rmse:1.75279
# [690]	validation_0-rmse:1.75222
# [691]	validation_0-rmse:1.75354
# [692]	validation_0-rmse:1.75506
# [693]	validation_0-rmse:1.75576
# [694]	validation_0-rmse:1.75453
# [695]	validation_0-rmse:1.75618
# [696]	validation_0-rmse:1.75946
# [697]	validation_0-rmse:1.76070
# [698]	validation_0-rmse:1.75914
# [699]	validation_0-rmse:1.76063
# [700]	validation_0-rmse:1.76127
# [701]	validation_0-rmse:1.75940
# [702]	validation_0-rmse:1.75667
# [703]	validation_0-rmse:1.76058
# [704]	validation_0-rmse:1.76062
# [705]	validation_0-rmse:1.76255
# [706]	validation_0-rmse:1.75913
# [707]	validation_0-rmse:1.75787
# [708]	validation_0-rmse:1.75476
# [709]	validation_0-rmse:1.75282
# [710]	validation_0-rmse:1.75611
# [711]	validation_0-rmse:1.75399
# [712]	validation_0-rmse:1.75421
# [713]	validation_0-rmse:1.75553
# [714]	validation_0-rmse:1.75630
# [715]	validation_0-rmse:1.75830
# [716]	validation_0-rmse:1.75665
# [717]	validation_0-rmse:1.75596
# [718]	validation_0-rmse:1.75347
# [719]	validation_0-rmse:1.75613
# [720]	validation_0-rmse:1.75306
# [721]	validation_0-rmse:1.75374
# [722]	validation_0-rmse:1.75248
# [723]	validation_0-rmse:1.75409
# [724]	validation_0-rmse:1.75651
# [725]	validation_0-rmse:1.75440
# [726]	validation_0-rmse:1.75376
# [727]	validation_0-rmse:1.75287
# [728]	validation_0-rmse:1.75221
# [729]	validation_0-rmse:1.75138
# [730]	validation_0-rmse:1.74999
# [731]	validation_0-rmse:1.74553
# [732]	validation_0-rmse:1.74672
# [733]	validation_0-rmse:1.74468
# [734]	validation_0-rmse:1.74738
# [735]	validation_0-rmse:1.74545
# [736]	validation_0-rmse:1.74611
# [737]	validation_0-rmse:1.74411
# [738]	validation_0-rmse:1.74302
# [739]	validation_0-rmse:1.74637
# [740]	validation_0-rmse:1.74388
# [741]	validation_0-rmse:1.74529
# [742]	validation_0-rmse:1.74234
# [743]	validation_0-rmse:1.74363
# [744]	validation_0-rmse:1.74311
# [745]	validation_0-rmse:1.74307
# [746]	validation_0-rmse:1.74227
# [747]	validation_0-rmse:1.74129
# [748]	validation_0-rmse:1.74323
# [749]	validation_0-rmse:1.74403
# [750]	validation_0-rmse:1.74561
# [751]	validation_0-rmse:1.74445
# [752]	validation_0-rmse:1.74151
# [753]	validation_0-rmse:1.74263
# [754]	validation_0-rmse:1.74094
# [755]	validation_0-rmse:1.74300
# [756]	validation_0-rmse:1.74249
# [757]	validation_0-rmse:1.74415
# [758]	validation_0-rmse:1.74199
# [759]	validation_0-rmse:1.74346
# [760]	validation_0-rmse:1.74539
# [761]	validation_0-rmse:1.74343
# [762]	validation_0-rmse:1.74709
# [763]	validation_0-rmse:1.74541
# [764]	validation_0-rmse:1.74643
# [765]	validation_0-rmse:1.74787
# [766]	validation_0-rmse:1.74605
# [767]	validation_0-rmse:1.74513
# [768]	validation_0-rmse:1.74273
# [769]	validation_0-rmse:1.74015
# [770]	validation_0-rmse:1.74346
# [771]	validation_0-rmse:1.74149
# [772]	validation_0-rmse:1.74402
# [773]	validation_0-rmse:1.74851
# [774]	validation_0-rmse:1.74475
# [775]	validation_0-rmse:1.74445
# [776]	validation_0-rmse:1.74468
# [777]	validation_0-rmse:1.74549
# [778]	validation_0-rmse:1.74368
# [779]	validation_0-rmse:1.74565
# [780]	validation_0-rmse:1.74452
# [781]	validation_0-rmse:1.74533
# [782]	validation_0-rmse:1.74815
# [783]	validation_0-rmse:1.74595
# [784]	validation_0-rmse:1.74382
# [785]	validation_0-rmse:1.74483
# [786]	validation_0-rmse:1.74699
# [787]	validation_0-rmse:1.75179
# [788]	validation_0-rmse:1.75492
# [789]	validation_0-rmse:1.75321
# [790]	validation_0-rmse:1.75465
# [791]	validation_0-rmse:1.74972
# [792]	validation_0-rmse:1.74834
# [793]	validation_0-rmse:1.74713
# [794]	validation_0-rmse:1.74556
# [795]	validation_0-rmse:1.74803
# [796]	validation_0-rmse:1.74671
# [797]	validation_0-rmse:1.74543
# [798]	validation_0-rmse:1.74791
# [799]	validation_0-rmse:1.74984
# [800]	validation_0-rmse:1.74881
# [801]	validation_0-rmse:1.74958
# [802]	validation_0-rmse:1.74894
# [803]	validation_0-rmse:1.74413
# [804]	validation_0-rmse:1.74742
# [805]	validation_0-rmse:1.74817
# [806]	validation_0-rmse:1.74922
# [807]	validation_0-rmse:1.74771
# [808]	validation_0-rmse:1.74516
# [809]	validation_0-rmse:1.74461
# [810]	validation_0-rmse:1.74713
# [811]	validation_0-rmse:1.74628
# [812]	validation_0-rmse:1.74364
# [813]	validation_0-rmse:1.74384
# [814]	validation_0-rmse:1.74539
# [815]	validation_0-rmse:1.74287
# [816]	validation_0-rmse:1.74355
# [817]	validation_0-rmse:1.74236
# [818]	validation_0-rmse:1.74142
# [819]	validation_0-rmse:1.74265
# [820]	validation_0-rmse:1.74301
# [821]	validation_0-rmse:1.74062
# [822]	validation_0-rmse:1.74316
# [823]	validation_0-rmse:1.74516
# [824]	validation_0-rmse:1.74389
# [825]	validation_0-rmse:1.74212
# [826]	validation_0-rmse:1.74371
# [827]	validation_0-rmse:1.74241
# [828]	validation_0-rmse:1.74097
# [829]	validation_0-rmse:1.74338
# [830]	validation_0-rmse:1.74101
# [831]	validation_0-rmse:1.73886
# [832]	validation_0-rmse:1.73748
# [833]	validation_0-rmse:1.73925
# [834]	validation_0-rmse:1.74036
# [835]	validation_0-rmse:1.73906
# [836]	validation_0-rmse:1.73961
# [837]	validation_0-rmse:1.74373
# [838]	validation_0-rmse:1.74429
# [839]	validation_0-rmse:1.74339
# [840]	validation_0-rmse:1.74493
# [841]	validation_0-rmse:1.74259
# [842]	validation_0-rmse:1.74739
# [843]	validation_0-rmse:1.74371
# [844]	validation_0-rmse:1.74165
# [845]	validation_0-rmse:1.74237
# [846]	validation_0-rmse:1.74004
# [847]	validation_0-rmse:1.74234
# [848]	validation_0-rmse:1.74105
# [849]	validation_0-rmse:1.73835
# [850]	validation_0-rmse:1.74096
# [851]	validation_0-rmse:1.74223
# [852]	validation_0-rmse:1.74114
# [853]	validation_0-rmse:1.74170
# [854]	validation_0-rmse:1.74277
# [855]	validation_0-rmse:1.74076
# [856]	validation_0-rmse:1.74237
# [857]	validation_0-rmse:1.74571
# [858]	validation_0-rmse:1.74343
# [859]	validation_0-rmse:1.74261
# [860]	validation_0-rmse:1.73956
# [861]	validation_0-rmse:1.73706
# [862]	validation_0-rmse:1.73808
# [863]	validation_0-rmse:1.74019
# [864]	validation_0-rmse:1.74256
# [865]	validation_0-rmse:1.74374
# [866]	validation_0-rmse:1.74633
# [867]	validation_0-rmse:1.74488
# [868]	validation_0-rmse:1.74488
# [869]	validation_0-rmse:1.74449
# [870]	validation_0-rmse:1.74397
# [871]	validation_0-rmse:1.74064
# [872]	validation_0-rmse:1.74153
# [873]	validation_0-rmse:1.74079
# [874]	validation_0-rmse:1.74302
# [875]	validation_0-rmse:1.74706
# [876]	validation_0-rmse:1.74595
# [877]	validation_0-rmse:1.74561
# [878]	validation_0-rmse:1.74627
# [879]	validation_0-rmse:1.74407
# [880]	validation_0-rmse:1.74652
# [881]	validation_0-rmse:1.74274
# [882]	validation_0-rmse:1.74146
# [883]	validation_0-rmse:1.73946
# [884]	validation_0-rmse:1.74109
# [885]	validation_0-rmse:1.74301
# [886]	validation_0-rmse:1.74576
# [887]	validation_0-rmse:1.74348
# [888]	validation_0-rmse:1.74514
# [889]	validation_0-rmse:1.75022
# [890]	validation_0-rmse:1.74858
# [891]	validation_0-rmse:1.74533
# [892]	validation_0-rmse:1.74608
# [893]	validation_0-rmse:1.74485
# [894]	validation_0-rmse:1.74728
# [895]	validation_0-rmse:1.74889
# [896]	validation_0-rmse:1.75159
# [897]	validation_0-rmse:1.75049
# [898]	validation_0-rmse:1.74680
# [899]	validation_0-rmse:1.74600
# [900]	validation_0-rmse:1.74374
# [901]	validation_0-rmse:1.74480
# [902]	validation_0-rmse:1.74272
# [903]	validation_0-rmse:1.74410
# [904]	validation_0-rmse:1.74152
# [905]	validation_0-rmse:1.73920
# [906]	validation_0-rmse:1.74039
# [907]	validation_0-rmse:1.73958
# [908]	validation_0-rmse:1.73836
# [909]	validation_0-rmse:1.74036
# [910]	validation_0-rmse:1.74317
# [911]	validation_0-rmse:1.74541
# [912]	validation_0-rmse:1.74460
# [913]	validation_0-rmse:1.74377
# [914]	validation_0-rmse:1.74056
# [915]	validation_0-rmse:1.73909
# [916]	validation_0-rmse:1.74114
# [917]	validation_0-rmse:1.73956
# [918]	validation_0-rmse:1.73875
# [919]	validation_0-rmse:1.73845
# [920]	validation_0-rmse:1.73908
# [921]	validation_0-rmse:1.73987
# [922]	validation_0-rmse:1.73967
# [923]	validation_0-rmse:1.73931
# [924]	validation_0-rmse:1.74005
# [925]	validation_0-rmse:1.74185
# [926]	validation_0-rmse:1.74047
# [927]	validation_0-rmse:1.73869
# [928]	validation_0-rmse:1.73803
# [929]	validation_0-rmse:1.73682
# [930]	validation_0-rmse:1.73563
# [931]	validation_0-rmse:1.73824
# [932]	validation_0-rmse:1.73738
# [933]	validation_0-rmse:1.74210
# [934]	validation_0-rmse:1.74360
# [935]	validation_0-rmse:1.74425
# [936]	validation_0-rmse:1.74510
# [937]	validation_0-rmse:1.74318
# [938]	validation_0-rmse:1.74162
# [939]	validation_0-rmse:1.74356
# [940]	validation_0-rmse:1.74165
# [941]	validation_0-rmse:1.74006
# [942]	validation_0-rmse:1.73904
# [943]	validation_0-rmse:1.74112
# [944]	validation_0-rmse:1.74333
# [945]	validation_0-rmse:1.74591
# [946]	validation_0-rmse:1.74690
# [947]	validation_0-rmse:1.74780
# [948]	validation_0-rmse:1.74589
# [949]	validation_0-rmse:1.74293
# [950]	validation_0-rmse:1.74152
# [951]	validation_0-rmse:1.74076
# [952]	validation_0-rmse:1.74066
# [953]	validation_0-rmse:1.74726
# [954]	validation_0-rmse:1.74589
# [955]	validation_0-rmse:1.74513
# [956]	validation_0-rmse:1.74703
# [957]	validation_0-rmse:1.74527
# [958]	validation_0-rmse:1.74850
# [959]	validation_0-rmse:1.74470
# [960]	validation_0-rmse:1.74175
# [961]	validation_0-rmse:1.74359
# [962]	validation_0-rmse:1.74159
# [963]	validation_0-rmse:1.74301
# [964]	validation_0-rmse:1.74723
# [965]	validation_0-rmse:1.74613
# [966]	validation_0-rmse:1.74675
# [967]	validation_0-rmse:1.74768
# [968]	validation_0-rmse:1.74809
# [969]	validation_0-rmse:1.74842
# [970]	validation_0-rmse:1.74518
# [971]	validation_0-rmse:1.74193
# [972]	validation_0-rmse:1.74124
# [973]	validation_0-rmse:1.74408
# [974]	validation_0-rmse:1.74266
# [975]	validation_0-rmse:1.74036
# [976]	validation_0-rmse:1.73761
# [977]	validation_0-rmse:1.73682
# [978]	validation_0-rmse:1.73809
# [979]	validation_0-rmse:1.73732
# [980]	validation_0-rmse:1.73836
# [981]	validation_0-rmse:1.73742
# [982]	validation_0-rmse:1.74022
# [983]	validation_0-rmse:1.74066
# [984]	validation_0-rmse:1.73953
# [985]	validation_0-rmse:1.73842
# [986]	validation_0-rmse:1.73955
# [987]	validation_0-rmse:1.74172
# [988]	validation_0-rmse:1.74118
# [989]	validation_0-rmse:1.74316
# [990]	validation_0-rmse:1.74759
# [991]	validation_0-rmse:1.74707
# [992]	validation_0-rmse:1.75063
# [993]	validation_0-rmse:1.74849
# [994]	validation_0-rmse:1.74512
# [995]	validation_0-rmse:1.74473
# [996]	validation_0-rmse:1.74347
# [997]	validation_0-rmse:1.74231
# [998]	validation_0-rmse:1.74301
# [999]	validation_0-rmse:1.74387
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.3,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=300,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, ...)

# %%
from sklearn.metrics import r2_score
y_predict = model.predict(x_valid)
r2_score(y_valid, y_predict)
# Out:
# 0.6073296495028624

# %%
# Out:
# array([1.0083811, 1.129292 , 1.0499312, ..., 2.5314405, 2.5314405,
#        2.5314405], dtype=float32)

# %%
np.array(y_train)
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
y_train
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 3142662    1.0
# 3142663    1.0
# 3142664    1.0
# 3142665    1.0
# 3142666    1.0
# Name: item_cnt_day, Length: 2875102, dtype: float64

# %%
xgboost.plot_importance(model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
confusion_matrix()
