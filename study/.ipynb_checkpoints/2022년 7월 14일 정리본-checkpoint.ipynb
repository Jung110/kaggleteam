# %%
# 사용할 모듈 불러오기 
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import re

# %%
# 데이터 불러오기
items = pd.read_csv("./data/items.csv")
shops = pd.read_csv("./data/shops.csv")
train = pd.read_csv("./data/sales_train.csv")
test = pd.read_csv("./data/test.csv")
item_categories = pd.read_csv('./data/item_categories.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Train
# ###  columns 뜻
#  - data  = 날짜
#  - date_block_num  = 한달 단위로 구분하기 편하게 하기 위한 데이터
#  - shop_id = 가게 id
#  - item_price = 아이템 가격
#  - item_cnt_day = 당일 해당 아이템이 팔린 개수

# %%
train.info() # null 값이 모든데이터에 존재 하지 않는다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
#  date의 자료형을 object  -> dattime 으로 바꾸고 싶다. 
# 변환하는 과정  ->
train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")
train["date"]. head(3)
# Out:
# 0   2013-01-02
# 1   2013-01-03
# 2   2013-01-05
# Name: date, dtype: datetime64[ns]

# %%
train.describe(include = 'all')
# Out:
# C:\Users\AW17R4\AppData\Local\Temp\ipykernel_15632\2740853986.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   train.describe(include = 'all')
#                        date  date_block_num       shop_id       item_id  \
# count               2935849    2.935849e+06  2.935849e+06  2.935849e+06
# unique                 1034             NaN           NaN           NaN
# top     2013-12-28 00:00:00             NaN           NaN           NaN
# freq                   9434             NaN           NaN           NaN
# first   2013-01-01 00:00:00             NaN           NaN           NaN
# last    2015-10-31 00:00:00             NaN           NaN           NaN
# mean                    NaN    1.456991e+01  3.300173e+01  1.019723e+04
# std                     NaN    9.422988e+00  1.622697e+01  6.324297e+03
# min                     NaN    0.000000e+00  0.000000e+00  0.000000e+00
# 25%                     NaN    7.000000e+00  2.200000e+01  4.476000e+03
# 50%                     NaN    1.400000e+01  3.100000e+01  9.343000e+03
# 75%                     NaN    2.300000e+01  4.700000e+01  1.568400e+04
# max                     NaN    3.300000e+01  5.900000e+01  2.216900e+04
#
#           item_price  item_cnt_day
# count   2.935849e+06  2.935849e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    8.908532e+02  1.242641e+00
# std     1.729800e+03  2.618834e+00
# min    -1.000000e+00 -2.200000e+01
# 25%     2.490000e+02  1.000000e+00
# 50%     3.990000e+02  1.000000e+00
# 75%     9.990000e+02  1.000000e+00
# max     3.079800e+05  2.169000e+03

# %% [markdown]
# 2013-01-01 00:00:00 ~ 2015-10-31 00:00:00  까지의 1034일간의 데이터임을 알수있다.
# item_price은 평균과 중위값의 차이가 심한 것으로 보아 이상치가 존재함을 알 수 있디.
# item_cnt_day 는일,이,삼 분위수가 1인데 비해 평균은 대략 1.2  최대값은 2168로 이상치가 존재한다.
# item_cnt_day, item_price에 최소값들은 음수이다.

# %%
def price_item_cnt_day_boxplot():
    plt.figure(figsize = (20,10))
    # item_price 의 박스플롯
    plt.subplot(1,2,1)
    sns.boxplot(x = 'date_block_num' , y= 'item_price',data =train)
    plt.title('item_price')
    plt.grid()
    # item_cnt_day의 박스 플롯
    plt.subplot(1,2,2)
    sns.boxplot(x = 'date_block_num' , y= 'item_cnt_day',data =train)
    plt.title('item_cnt_day')
    plt.grid()
price_item_cnt_day_boxplot()

# %% [markdown]
# - 다음은 date_block_num 별로 item_price의 boxplot이다.
# - 위의 그래프를 기준으로 item_price는 50000 이상 , item_cnt_day 는 1000 이상을 이상치로서 train에서 제거한다.
# - 또한 판매되는 수량을 구하는 것이 목적이므로 0미만의 값을 제거한다.

# %%
condition_for_drop = ((train["item_price"] >= 50000) | (train["item_price"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

condition_for_drop = ((train["item_cnt_day"] >= 1000) | (train["item_cnt_day"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

# %%
# 제거 후의 boxplot
price_item_cnt_day_boxplot()

# %%
train.corr()
# Out:
#                 date_block_num   shop_id   item_id  item_price  item_cnt_day
# date_block_num        1.000000  0.019329  0.009472    0.095539      0.010339
# shop_id               0.019329  1.000000  0.029345   -0.023955     -0.005660
# item_id               0.009472  0.029345  1.000000   -0.134812      0.018896
# item_price            0.095539 -0.023955 -0.134812    1.000000      0.014444
# item_cnt_day          0.010339 -0.005660  0.018896    0.014444      1.000000

# %% [markdown]
# ## shops

# %%
shops.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
shops.head(20)
# Out:
#                          shop_name  shop_id
# 0    !Якутск Орджоникидзе, 56 фран        0
# 1    !Якутск ТЦ "Центральный" фран        1
# 2                 Адыгея ТЦ "Мега"        2
# 3   Балашиха ТРК "Октябрь-Киномир"        3
# 4         Волжский ТЦ "Волга Молл"        4
# 5           Вологда ТРЦ "Мармелад"        5
# 6       Воронеж (Плехановская, 13)        6
# 7           Воронеж ТРЦ "Максимир"        7
# 8     Воронеж ТРЦ Сити-Парк "Град"        8
# 9                Выездная Торговля        9
# 10      Жуковский ул. Чкалова 39м?       10
# 11      Жуковский ул. Чкалова 39м²       11
# 12             Интернет-магазин ЧС       12
# 13             Казань ТЦ "Бехетле"       13
# 14         Казань ТЦ "ПаркХаус" II       14
# 15            Калуга ТРЦ "XXI век"       15
# 16                Коломна ТЦ "Рио"       16
# 17   Красноярск ТЦ "Взлетка Плаза"       17
# 18            Красноярск ТЦ "Июнь"       18
# 19           Курск ТЦ "Пушкинский"       19

# %% [markdown]
# - 이름에 특수문자가 들어가고 중복되는 이름들이 보인다

# %%
def clean_text(inputString):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
    return text_rmv
shops_names = shops["shop_name"].apply(clean_text)
shops_id = shops["shop_id"]
# 중복되는 이름 확인 
for i in list(zip(shops_names ,shops_id)):
    for j in list(zip(shops_names ,shops_id)):
        if (re.match('.*'+i[0]+'*.',j[0])) and (i[1]!= j[1]):
            print('code : ', i[1], ' and  ', j[1])
            print('name : ', i[0], ' and  ', j[0])
# Out:
# code :  10  and   11
# name :  Жуковский ул  Чкалова 39м   and   Жуковский ул  Чкалова 39м²
# code :  11  and   10
# name :  Жуковский ул  Чкалова 39м²  and   Жуковский ул  Чкалова 39м
# code :  39  and   40
# name :  РостовНаДону ТРК  Мегацентр Горизонт   and   РостовНаДону ТРК  Мегацентр Горизонт  Островной
# code :  57  and   0
# name :  Якутск Орджоникидзе  56  and    Якутск Орджоникидзе  56 фран
# code :  58  and   1
# name :  Якутск ТЦ  Центральный   and    Якутск ТЦ  Центральный  фран

# %% [markdown]
# - 위와 같이 shop id가 10:11, 39:40, 57:0, 58:1 4개의 아이디가 중복되는 것을 알 수 있다.
# - 위의 데이터를 기준으로 train data의 shop id를 바꾸어준다

# %%
train["shop_id"] = train["shop_id"].replace({0: 57, 1: 58, 11: 10, 40: 39})

# %% [markdown]
# ## items

# %%
items.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items.head(20) # 이름에 특수 문자 제거 후 비슷한 게임끼리
# Out:
#                                             item_name  item_id  \
# 0           ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1   !ABBYY FineReader 12 Professional Edition Full...        1
# 2       ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3     ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4         ***КОРОБКА (СТЕКЛО)                       D        4
# 5   ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6            ***УДАР ПО ВОРОТАМ (UNI)               D        6
# 7          ***УДАР ПО ВОРОТАМ-2 (UNI)               D        7
# 8            ***ЧАЙ С МУССОЛИНИ                     D        8
# 9       ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D        9
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D       10
# 11          *ЛИНИЯ СМЕРТИ                           D       11
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12
# 13          *СПАСАЯ ЭМИЛИ                           D       13
# 14          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D       14
# 15             //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ (Регион)       15
# 16                         //МОНГОЛ С.Бодров (Регион)       16
# 17                    //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА (Регион)       17
# 18          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D       18
# 19                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72       19
#
#     item_category_id
# 0                 40
# 1                 76
# 2                 40
# 3                 40
# 4                 40
# 5                 40
# 6                 40
# 7                 40
# 8                 40
# 9                 40
# 10                40
# 11                40
# 12                55
# 13                40
# 14                40
# 15                40
# 16                40
# 17                40
# 18                40
# 19                40

# %%
plt.figure(figsize=(20,10))
sns.countplot(x= 'item_category_id' , data = items)
plt.xticks(size = 15 , rotation =  45 , color = 'black')
plt.show()

# %%
item_categories[item_categories['item_category_id']==40]
# Out:
#    item_category_name  item_category_id
# 40         Кино - DVD                40

# %% [markdown]
# - item_category_id =40 인  Кино - DVD 카테고리에 많은 아이템이 존재하는지 알 수 있다

# %% [markdown]
# ## item_category

# %%
item_categories.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories.head(20)
# Out:
#             item_category_name  item_category_id
# 0      PC - Гарнитуры/Наушники                 0
# 1             Аксессуары - PS2                 1
# 2             Аксессуары - PS3                 2
# 3             Аксессуары - PS4                 3
# 4             Аксессуары - PSP                 4
# 5          Аксессуары - PSVita                 5
# 6        Аксессуары - XBOX 360                 6
# 7        Аксессуары - XBOX ONE                 7
# 8               Билеты (Цифра)                 8
# 9              Доставка товара                 9
# 10       Игровые консоли - PS2                10
# 11       Игровые консоли - PS3                11
# 12       Игровые консоли - PS4                12
# 13       Игровые консоли - PSP                13
# 14    Игровые консоли - PSVita                14
# 15  Игровые консоли - XBOX 360                15
# 16  Игровые консоли - XBOX ONE                16
# 17    Игровые консоли - Прочие                17
# 18                  Игры - PS2                18
# 19                  Игры - PS3                19

# %% [markdown]
# - item_category_name에 같은 단어가 들어가는 데이터가 많이 존재한다
# - 이를 묶어 더 큰 범주를 만들 수 있다.

# %% [markdown]
# ## test

# %%
test.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB

# %%
# test의 shop_id , item_id 기 train 데이터에 있는지 확인
diff_test_train_shop_id  = set(test['shop_id']) - set(train['shop_id'])
print('diffrent shop_id nums: ',len(diff_test_train_shop_id))
diff_test_train_item_id = set(test['item_id']) - set(train['item_id'])
print('diffrent item_id nums: ',len(diff_test_train_item_id))
diff_test_items_item_id = set(test['item_id']) - set(items['item_id'])
print('diff_test_items_itemid nums: ',len(diff_test_items_item_id))
# Out:
# diffrent shop_id nums:  0
# diffrent item_id nums:  363
# diff_test_items_itemid nums:  0

# %% [markdown]
# #### test에는 존재하지만 train에 존재하지 않는 값이 363개 존재한다.
# #### items에는 test에 있는 모든 item_id를 가지고 있다.
# #### 이를 해결하기위해 다음과 같은 방법을 사용한다
#  - train에 존재하지 않는 test값을 예측하기 위해 item_category_id를 사용한다.

# %% [markdown]
# ## high_category

# %% [markdown]
# item_category의 앞부분만 자르고 새롭게 만든 열을 라벨인코딩 (악세사리 >> 1)
# item_id와 연결되어있는 item_category를 새롭게 만든 열로 연결하여 test값을 예측한다면?

# %%
# item_category 분류하여 새로운 열 만들기
def make_high_category(data_name_col):
    '''
    상위 분류를 생성후 라벨 인코딩을 하는 함수
    shopname 과 item_category_name 에 사용
    '''
    data_name_col
    data_name_col = data_name_col.apply(clean_text)
    high_category_name = data_name_col.str.split(' ')
    high_category_name = [data[1] if data[0] == '' else data[0] for data in high_category_name]
    high_category_name_le = LabelEncoder()
    high_category_name_le.fit(high_category_name)
    high_category_id = high_category_name_le.transform(high_category_name)
    return high_category_name , high_category_id

# %%
item_categories['high_category_name'] , item_categories['high_category_id'] =\
make_high_category(item_categories.item_category_name)

# %%
item_categories.head(3)
# Out:
#         item_category_name  item_category_id high_category_name  \
# 0  PC - Гарнитуры/Наушники                 0                 PC
# 1         Аксессуары - PS2                 1         Аксессуары
# 2         Аксессуары - PS3                 2         Аксессуары
#
#    high_category_id
# 0                 0
# 1                 1
# 2                 1

# %%
shops['city_name'],shops['city_id'] = make_high_category(shops.shop_name)

# %%
shops.head(3)
# Out:
#                        shop_name  shop_id city_name  city_id
# 0  !Якутск Орджоникидзе, 56 фран        0    Якутск       29
# 1  !Якутск ТЦ "Центральный" фран        1    Якутск       29
# 2               Адыгея ТЦ "Мега"        2    Адыгея        0

# %% [markdown]
# ## train + test

# %%
'''
test에 없는 열을 추가 해야 하거나
train에 쓸모없는 데이터를 제거해야 한다. 
'''
test.columns , train.columns
# Out:
# (Index(['ID', 'shop_id', 'item_id'], dtype='object'),
#  Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#         'item_cnt_day'],
#        dtype='object'))

# %%
test['date_block_num'] = 34
test['item_price'] = 1
test['item_cnt_day'] = 0
del train['date']
del test['ID']

# %%
test.columns , train.columns
# Out:
# (Index(['shop_id', 'item_id', 'date_block_num', 'item_price', 'item_cnt_day'], dtype='object'),
#  Index(['date_block_num', 'shop_id', 'item_id', 'item_price', 'item_cnt_day'], dtype='object'))

# %%
# 인덱스 값이 꼬여있다.
pd.concat([test,train])
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0              5     5037              34         1.0           0.0
# 1              5     5320              34         1.0           0.0
# 2              5     5233              34         1.0           0.0
# 3              5     5232              34         1.0           0.0
# 4              5     5268              34         1.0           0.0
# ...          ...      ...             ...         ...           ...
# 2935844       25     7409              33       299.0           1.0
# 2935845       25     7460              33       299.0           1.0
# 2935846       25     7459              33       349.0           1.0
# 2935847       25     7440              33       299.0           1.0
# 2935848       25     7460              33       299.0           1.0
#
# [3142687 rows x 5 columns]

# %%
pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0             16    18336               0       299.0           1.0
# 1             25    18631               0       149.0           1.0
# 2             25    19333               0       350.0           1.0
# 3             25    19330               0       349.0           1.0
# 4             25    18546               0       149.0           1.0
# ...          ...      ...             ...         ...           ...
# 3142682       57    18454              34         1.0           0.0
# 3142683       57    18027              34         1.0           0.0
# 3142684       57    18049              34         1.0           0.0
# 3142685       57    18589              34         1.0           0.0
# 3142686        5     5037              34         1.0           0.0
#
# [3142687 rows x 5 columns]

# %%
sales_df = pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)

# %%
sales_df = pd.merge(sales_df ,shops ,on =  'shop_id').drop(['shop_name','city_name'] ,axis =1)

# %%
sales_df.head(3)
# Out:
#    shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id
# 0       16    18336               0       299.0           1.0       10
# 1       16    21347               0       549.0           1.0       10
# 2       16    20890               0      1899.0           1.0       10

# %%
item_high_categories = items.merge(item_categories).drop(['item_name','item_category_name','high_category_name'],axis = 1)
item_high_categories.head(3)
# Out:
#    item_id  item_category_id  high_category_id
# 0        0                40                 7
# 1        2                40                 7
# 2        3                40                 7

# %%
sales_df = pd.merge(sales_df ,item_high_categories ,on =  'item_id')

# %%
sales_df['item_revenue_day'] = sales_df.item_cnt_day * sales_df.item_price

# %%
sales_df.head(3)
# Out:
#    shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id  \
# 0       16    18336               0       299.0           1.0       10
# 1       25    18336               0       299.0           1.0       13
# 2       25    18336               1       299.0           1.0       13
#
#    item_category_id  high_category_id  item_revenue_day
# 0                57                 9             299.0
# 1                57                 9             299.0
# 2                57                 9             299.0

# %%
base_item_feature_names = ['item_id','item_category_id','high_category_id']
base_place_feature_names = ['shop_id','city_id']
mean_feature_names = ['item_cnt_day','item_revenue_day']

# %%
def add_mean_feature(df , base_feature_names ,mean_feature_names):
    '''
    base_feature_name를 기준으로 mean_feature_names의 값들을 
    한달 평균을 구해서 df에 병합해주는 함수
    '''
    df_pivot  = df[list(base_feature_names) + list(mean_feature_names)]
    col_name = ''
    for base_feature_name in base_feature_names:
        if base_feature_name !='date_block_num':
            col_name += '_'.join(base_feature_name.split('_')[:-1])+'_'

    for mean_feature_name in mean_feature_names:
        df_pivot = df_pivot.rename(columns = {mean_feature_name:col_name + mean_feature_name.split('_')[1]+'_month_mean'})

    df_pivot = df_pivot.pivot_table(index = base_feature_names)
    df = df.merge(df_pivot , on =base_feature_names)
    return df

# %%
for place in base_place_feature_names:
    for item in base_item_feature_names:
        base_feature_names = ['date_block_num', place,item]
        sales_df = add_mean_feature(sales_df ,base_feature_names,mean_feature_names)

# %%
sales_df.columns
# Out:
# Index(['shop_id', 'item_id', 'date_block_num', 'item_price', 'item_cnt_day',
#        'city_id', 'item_category_id', 'high_category_id', 'item_revenue_day',
#        'shop_item_cnt_month_mean', 'shop_item_revenue_month_mean',
#        'shop_item_category_cnt_month_mean',
#        'shop_item_category_revenue_month_mean',
#        'shop_high_category_cnt_month_mean',
#        'shop_high_category_revenue_month_mean', 'city_item_cnt_month_mean',
#        'city_item_revenue_month_mean', 'city_item_category_cnt_month_mean',
#        'city_item_category_revenue_month_mean',
#        'city_high_category_cnt_month_mean',
#        'city_high_category_revenue_month_mean'],
#       dtype='object')

# %% [markdown]
# # drop uslessID

# %%
sales_df.drop(base_item_feature_names+base_place_feature_names , axis =1  , inplace = True)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(sales_df.corr() , annot=True)
plt.show()

# %% [markdown]
# # Holdsout

# %%
x_train = sales_df[sales_df['date_block_num'] < 33]
x_train = x_train.drop(['item_cnt_day'], axis = 1)
y_train = sales_df[sales_df['date_block_num'] < 33]['item_cnt_day']


x_valid = sales_df[sales_df['date_block_num'] == 33]
x_valid = x_valid.drop(['item_cnt_day'], axis = 1)
y_valid = sales_df[sales_df['date_block_num'] == 33]['item_cnt_day']

x_test = sales_df[sales_df['date_block_num'] == 34]
x_test = x_test.drop(['item_cnt_day'], axis = 1)
y_test = sales_df[sales_df['date_block_num'] == 34]['item_cnt_day']

# %% [markdown]
# # XGboost

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    x_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set= [(x_valid, y_valid)], 
    verbose=True, 
    early_stopping_rounds = 150)
# Out:
# C:\Users\AW17R4\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\AW17R4\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:2.54621
# [1]	validation_0-rmse:2.36864
# [2]	validation_0-rmse:2.23757
# [3]	validation_0-rmse:2.13704
# [4]	validation_0-rmse:2.08490
# [5]	validation_0-rmse:2.03264
# [6]	validation_0-rmse:2.02294
# [7]	validation_0-rmse:2.00528
# [8]	validation_0-rmse:2.00529
# [9]	validation_0-rmse:1.99106
# [10]	validation_0-rmse:1.97657
# [11]	validation_0-rmse:1.98121
# [12]	validation_0-rmse:1.96838
# [13]	validation_0-rmse:1.97652
# [14]	validation_0-rmse:1.98318
# [15]	validation_0-rmse:1.96382
# [16]	validation_0-rmse:1.95935
# [17]	validation_0-rmse:1.95018
# [18]	validation_0-rmse:1.95968
# [19]	validation_0-rmse:1.94884
# [20]	validation_0-rmse:1.96025
# [21]	validation_0-rmse:1.94794
# [22]	validation_0-rmse:1.94304
# [23]	validation_0-rmse:1.93839
# [24]	validation_0-rmse:1.94825
# [25]	validation_0-rmse:1.94591
# [26]	validation_0-rmse:1.95687
# [27]	validation_0-rmse:1.94886
# [28]	validation_0-rmse:1.93930
# [29]	validation_0-rmse:1.93418
# [30]	validation_0-rmse:1.94043
# [31]	validation_0-rmse:1.92864
# [32]	validation_0-rmse:1.92024
# [33]	validation_0-rmse:1.92906
# [34]	validation_0-rmse:1.92233
# [35]	validation_0-rmse:1.92109
# [36]	validation_0-rmse:1.92831
# [37]	validation_0-rmse:1.92069
# [38]	validation_0-rmse:1.92804
# [39]	validation_0-rmse:1.91979
# [40]	validation_0-rmse:1.91443
# [41]	validation_0-rmse:1.90879
# [42]	validation_0-rmse:1.91389
# [43]	validation_0-rmse:1.91468
# [44]	validation_0-rmse:1.92089
# [45]	validation_0-rmse:1.91637
# [46]	validation_0-rmse:1.91338
# [47]	validation_0-rmse:1.90979
# [48]	validation_0-rmse:1.91945
# [49]	validation_0-rmse:1.92273
# [50]	validation_0-rmse:1.93028
# [51]	validation_0-rmse:1.93432
# [52]	validation_0-rmse:1.93636
# [53]	validation_0-rmse:1.93278
# [54]	validation_0-rmse:1.93632
# [55]	validation_0-rmse:1.93307
# [56]	validation_0-rmse:1.92719
# [57]	validation_0-rmse:1.92482
# [58]	validation_0-rmse:1.92156
# [59]	validation_0-rmse:1.92978
# [60]	validation_0-rmse:1.92587
# [61]	validation_0-rmse:1.92224
# [62]	validation_0-rmse:1.92659
# [63]	validation_0-rmse:1.92244
# [64]	validation_0-rmse:1.92800
# [65]	validation_0-rmse:1.92214
# [66]	validation_0-rmse:1.92118
# [67]	validation_0-rmse:1.93038
# [68]	validation_0-rmse:1.93228
# [69]	validation_0-rmse:1.92862
# [70]	validation_0-rmse:1.93641
# [71]	validation_0-rmse:1.92928
# [72]	validation_0-rmse:1.92560
# [73]	validation_0-rmse:1.92397
# [74]	validation_0-rmse:1.93000
# [75]	validation_0-rmse:1.92355
# [76]	validation_0-rmse:1.92163
# [77]	validation_0-rmse:1.91746
# [78]	validation_0-rmse:1.91486
# [79]	validation_0-rmse:1.91046
# [80]	validation_0-rmse:1.90840
# [81]	validation_0-rmse:1.90958
# [82]	validation_0-rmse:1.91432
# [83]	validation_0-rmse:1.91749
# [84]	validation_0-rmse:1.91164
# [85]	validation_0-rmse:1.91816
# [86]	validation_0-rmse:1.91676
# [87]	validation_0-rmse:1.91290
# [88]	validation_0-rmse:1.91163
# [89]	validation_0-rmse:1.90759
# [90]	validation_0-rmse:1.91191
# [91]	validation_0-rmse:1.90818
# [92]	validation_0-rmse:1.90131
# [93]	validation_0-rmse:1.89918
# [94]	validation_0-rmse:1.89616
# [95]	validation_0-rmse:1.89854
# [96]	validation_0-rmse:1.90082
# [97]	validation_0-rmse:1.90459
# [98]	validation_0-rmse:1.90438
# [99]	validation_0-rmse:1.90138
# [100]	validation_0-rmse:1.89993
# [101]	validation_0-rmse:1.89365
# [102]	validation_0-rmse:1.88966
# [103]	validation_0-rmse:1.89611
# [104]	validation_0-rmse:1.89160
# [105]	validation_0-rmse:1.88772
# [106]	validation_0-rmse:1.88717
# [107]	validation_0-rmse:1.88746
# [108]	validation_0-rmse:1.89228
# [109]	validation_0-rmse:1.89043
# [110]	validation_0-rmse:1.88378
# [111]	validation_0-rmse:1.88858
# [112]	validation_0-rmse:1.88429
# [113]	validation_0-rmse:1.88237
# [114]	validation_0-rmse:1.88187
# [115]	validation_0-rmse:1.87662
# [116]	validation_0-rmse:1.87859
# [117]	validation_0-rmse:1.87752
# [118]	validation_0-rmse:1.87383
# [119]	validation_0-rmse:1.87890
# [120]	validation_0-rmse:1.87472
# [121]	validation_0-rmse:1.87302
# [122]	validation_0-rmse:1.87140
# [123]	validation_0-rmse:1.86912
# [124]	validation_0-rmse:1.86624
# [125]	validation_0-rmse:1.87004
# [126]	validation_0-rmse:1.86839
# [127]	validation_0-rmse:1.87316
# [128]	validation_0-rmse:1.87569
# [129]	validation_0-rmse:1.87364
# [130]	validation_0-rmse:1.87135
# [131]	validation_0-rmse:1.86919
# [132]	validation_0-rmse:1.86803
# [133]	validation_0-rmse:1.86988
# [134]	validation_0-rmse:1.87119
# [135]	validation_0-rmse:1.86843
# [136]	validation_0-rmse:1.86766
# [137]	validation_0-rmse:1.86450
# [138]	validation_0-rmse:1.86274
# [139]	validation_0-rmse:1.86145
# [140]	validation_0-rmse:1.85747
# [141]	validation_0-rmse:1.86126
# [142]	validation_0-rmse:1.86017
# [143]	validation_0-rmse:1.86152
# [144]	validation_0-rmse:1.85851
# [145]	validation_0-rmse:1.85799
# [146]	validation_0-rmse:1.85577
# [147]	validation_0-rmse:1.85877
# [148]	validation_0-rmse:1.85636
# [149]	validation_0-rmse:1.85324
# [150]	validation_0-rmse:1.85219
# [151]	validation_0-rmse:1.85082
# [152]	validation_0-rmse:1.84847
# [153]	validation_0-rmse:1.84695
# [154]	validation_0-rmse:1.84631
# [155]	validation_0-rmse:1.84141
# [156]	validation_0-rmse:1.83990
# [157]	validation_0-rmse:1.83662
# [158]	validation_0-rmse:1.83830
# [159]	validation_0-rmse:1.83458
# [160]	validation_0-rmse:1.83867
# [161]	validation_0-rmse:1.83535
# [162]	validation_0-rmse:1.83427
# [163]	validation_0-rmse:1.83365
# [164]	validation_0-rmse:1.83612
# [165]	validation_0-rmse:1.83223
# [166]	validation_0-rmse:1.83532
# [167]	validation_0-rmse:1.83559
# [168]	validation_0-rmse:1.83400
# [169]	validation_0-rmse:1.83427
# [170]	validation_0-rmse:1.83519
# [171]	validation_0-rmse:1.83321
# [172]	validation_0-rmse:1.83228
# [173]	validation_0-rmse:1.82913
# [174]	validation_0-rmse:1.82900
# [175]	validation_0-rmse:1.82725
# [176]	validation_0-rmse:1.82337
# [177]	validation_0-rmse:1.82695
# [178]	validation_0-rmse:1.82617
# [179]	validation_0-rmse:1.82399
# [180]	validation_0-rmse:1.82135
# [181]	validation_0-rmse:1.81814
# [182]	validation_0-rmse:1.81752
# [183]	validation_0-rmse:1.81960
# [184]	validation_0-rmse:1.81808
# [185]	validation_0-rmse:1.82159
# [186]	validation_0-rmse:1.81944
# [187]	validation_0-rmse:1.81967
# [188]	validation_0-rmse:1.81509
# [189]	validation_0-rmse:1.81297
# [190]	validation_0-rmse:1.81317
# [191]	validation_0-rmse:1.81250
# [192]	validation_0-rmse:1.81164
# [193]	validation_0-rmse:1.80913
# [194]	validation_0-rmse:1.80911
# [195]	validation_0-rmse:1.80698
# [196]	validation_0-rmse:1.80748
# [197]	validation_0-rmse:1.80525
# [198]	validation_0-rmse:1.80843
# [199]	validation_0-rmse:1.81089
# [200]	validation_0-rmse:1.81045
# [201]	validation_0-rmse:1.80835
# [202]	validation_0-rmse:1.80707
# [203]	validation_0-rmse:1.80651
# [204]	validation_0-rmse:1.80664
# [205]	validation_0-rmse:1.80179
# [206]	validation_0-rmse:1.80429
# [207]	validation_0-rmse:1.80090
# [208]	validation_0-rmse:1.79830
# [209]	validation_0-rmse:1.79481
# [210]	validation_0-rmse:1.79446
# [211]	validation_0-rmse:1.79565
# [212]	validation_0-rmse:1.79668
# [213]	validation_0-rmse:1.79512
# [214]	validation_0-rmse:1.79655
# [215]	validation_0-rmse:1.79427
# [216]	validation_0-rmse:1.79399
# [217]	validation_0-rmse:1.79604
# [218]	validation_0-rmse:1.79577
# [219]	validation_0-rmse:1.79793
# [220]	validation_0-rmse:1.79734
# [221]	validation_0-rmse:1.79266
# [222]	validation_0-rmse:1.79406
# [223]	validation_0-rmse:1.79747
# [224]	validation_0-rmse:1.79663
# [225]	validation_0-rmse:1.79142
# [226]	validation_0-rmse:1.79351
# [227]	validation_0-rmse:1.79101
# [228]	validation_0-rmse:1.79575
# [229]	validation_0-rmse:1.79620
# [230]	validation_0-rmse:1.79351
# [231]	validation_0-rmse:1.79230
# [232]	validation_0-rmse:1.79112
# [233]	validation_0-rmse:1.78915
# [234]	validation_0-rmse:1.78999
# [235]	validation_0-rmse:1.78797
# [236]	validation_0-rmse:1.78663
# [237]	validation_0-rmse:1.78494
# [238]	validation_0-rmse:1.78654
# [239]	validation_0-rmse:1.78672
# [240]	validation_0-rmse:1.78815
# [241]	validation_0-rmse:1.78619
# [242]	validation_0-rmse:1.78556
# [243]	validation_0-rmse:1.78802
# [244]	validation_0-rmse:1.78964
# [245]	validation_0-rmse:1.79005
# [246]	validation_0-rmse:1.79020
# [247]	validation_0-rmse:1.78841
# [248]	validation_0-rmse:1.78970
# [249]	validation_0-rmse:1.79282
# [250]	validation_0-rmse:1.79272
# [251]	validation_0-rmse:1.79360
# [252]	validation_0-rmse:1.79255
# [253]	validation_0-rmse:1.78953
# [254]	validation_0-rmse:1.78937
# [255]	validation_0-rmse:1.78768
# [256]	validation_0-rmse:1.78871
# [257]	validation_0-rmse:1.78914
# [258]	validation_0-rmse:1.79300
# [259]	validation_0-rmse:1.79120
# [260]	validation_0-rmse:1.78808
# [261]	validation_0-rmse:1.78564
# [262]	validation_0-rmse:1.78319
# [263]	validation_0-rmse:1.78523
# [264]	validation_0-rmse:1.78353
# [265]	validation_0-rmse:1.77373
# [266]	validation_0-rmse:1.77050
# [267]	validation_0-rmse:1.76993
# [268]	validation_0-rmse:1.77364
# [269]	validation_0-rmse:1.77475
# [270]	validation_0-rmse:1.77450
# [271]	validation_0-rmse:1.77486
# [272]	validation_0-rmse:1.77511
# [273]	validation_0-rmse:1.77658
# [274]	validation_0-rmse:1.77654
# [275]	validation_0-rmse:1.77889
# [276]	validation_0-rmse:1.77931
# [277]	validation_0-rmse:1.77865
# [278]	validation_0-rmse:1.77789
# [279]	validation_0-rmse:1.77942
# [280]	validation_0-rmse:1.78274
# [281]	validation_0-rmse:1.77895
# [282]	validation_0-rmse:1.78081
# [283]	validation_0-rmse:1.78260
# [284]	validation_0-rmse:1.78106
# [285]	validation_0-rmse:1.78136
# [286]	validation_0-rmse:1.78005
# [287]	validation_0-rmse:1.78302
# [288]	validation_0-rmse:1.78238
# [289]	validation_0-rmse:1.78291
# [290]	validation_0-rmse:1.78135
# [291]	validation_0-rmse:1.78110
# [292]	validation_0-rmse:1.78142
# [293]	validation_0-rmse:1.78061
# [294]	validation_0-rmse:1.78255
# [295]	validation_0-rmse:1.78131
# [296]	validation_0-rmse:1.78251
# [297]	validation_0-rmse:1.78445
# [298]	validation_0-rmse:1.78380
# [299]	validation_0-rmse:1.78441
# [300]	validation_0-rmse:1.78188
# [301]	validation_0-rmse:1.77983
# [302]	validation_0-rmse:1.78022
# [303]	validation_0-rmse:1.78807
# [304]	validation_0-rmse:1.78595
# [305]	validation_0-rmse:1.78283
# [306]	validation_0-rmse:1.78091
# [307]	validation_0-rmse:1.78204
# [308]	validation_0-rmse:1.78487
# [309]	validation_0-rmse:1.78782
# [310]	validation_0-rmse:1.78488
# [311]	validation_0-rmse:1.78242
# [312]	validation_0-rmse:1.78322
# [313]	validation_0-rmse:1.78181
# [314]	validation_0-rmse:1.78594
# [315]	validation_0-rmse:1.78436
# [316]	validation_0-rmse:1.78276
# [317]	validation_0-rmse:1.77935
# [318]	validation_0-rmse:1.77753
# [319]	validation_0-rmse:1.77534
# [320]	validation_0-rmse:1.77371
# [321]	validation_0-rmse:1.77460
# [322]	validation_0-rmse:1.77643
# [323]	validation_0-rmse:1.77951
# [324]	validation_0-rmse:1.77791
# [325]	validation_0-rmse:1.77496
# [326]	validation_0-rmse:1.77780
# [327]	validation_0-rmse:1.77629
# [328]	validation_0-rmse:1.77556
# [329]	validation_0-rmse:1.77506
# [330]	validation_0-rmse:1.77378
# [331]	validation_0-rmse:1.77355
# [332]	validation_0-rmse:1.77584
# [333]	validation_0-rmse:1.77523
# [334]	validation_0-rmse:1.77333
# [335]	validation_0-rmse:1.77201
# [336]	validation_0-rmse:1.77219
# [337]	validation_0-rmse:1.77137
# [338]	validation_0-rmse:1.77416
# [339]	validation_0-rmse:1.77278
# [340]	validation_0-rmse:1.77276
# [341]	validation_0-rmse:1.77193
# [342]	validation_0-rmse:1.77265
# [343]	validation_0-rmse:1.77116
# [344]	validation_0-rmse:1.77139
# [345]	validation_0-rmse:1.77306
# [346]	validation_0-rmse:1.77302
# [347]	validation_0-rmse:1.77350
# [348]	validation_0-rmse:1.77262
# [349]	validation_0-rmse:1.77353
# [350]	validation_0-rmse:1.77463
# [351]	validation_0-rmse:1.77494
# [352]	validation_0-rmse:1.77513
# [353]	validation_0-rmse:1.77401
# [354]	validation_0-rmse:1.77427
# [355]	validation_0-rmse:1.76979
# [356]	validation_0-rmse:1.77154
# [357]	validation_0-rmse:1.77168
# [358]	validation_0-rmse:1.76904
# [359]	validation_0-rmse:1.77006
# [360]	validation_0-rmse:1.76923
# [361]	validation_0-rmse:1.77082
# [362]	validation_0-rmse:1.77044
# [363]	validation_0-rmse:1.76988
# [364]	validation_0-rmse:1.77155
# [365]	validation_0-rmse:1.76960
# [366]	validation_0-rmse:1.76722
# [367]	validation_0-rmse:1.76873
# [368]	validation_0-rmse:1.76744
# [369]	validation_0-rmse:1.77034
# [370]	validation_0-rmse:1.76981
# [371]	validation_0-rmse:1.77037
# [372]	validation_0-rmse:1.76791
# [373]	validation_0-rmse:1.76615
# [374]	validation_0-rmse:1.76629
# [375]	validation_0-rmse:1.76451
# [376]	validation_0-rmse:1.76563
# [377]	validation_0-rmse:1.76729
# [378]	validation_0-rmse:1.76459
# [379]	validation_0-rmse:1.76459
# [380]	validation_0-rmse:1.76753
# [381]	validation_0-rmse:1.76616
# [382]	validation_0-rmse:1.76810
# [383]	validation_0-rmse:1.76781
# [384]	validation_0-rmse:1.76737
# [385]	validation_0-rmse:1.76676
# [386]	validation_0-rmse:1.76361
# [387]	validation_0-rmse:1.76607
# [388]	validation_0-rmse:1.76232
# [389]	validation_0-rmse:1.76129
# [390]	validation_0-rmse:1.76064
# [391]	validation_0-rmse:1.76011
# [392]	validation_0-rmse:1.75952
# [393]	validation_0-rmse:1.75990
# [394]	validation_0-rmse:1.75811
# [395]	validation_0-rmse:1.75922
# [396]	validation_0-rmse:1.76091
# [397]	validation_0-rmse:1.76022
# [398]	validation_0-rmse:1.76354
# [399]	validation_0-rmse:1.76364
# [400]	validation_0-rmse:1.76278
# [401]	validation_0-rmse:1.76432
# [402]	validation_0-rmse:1.76962
# [403]	validation_0-rmse:1.76938
# [404]	validation_0-rmse:1.76689
# [405]	validation_0-rmse:1.76604
# [406]	validation_0-rmse:1.76486
# [407]	validation_0-rmse:1.76467
# [408]	validation_0-rmse:1.76435
# [409]	validation_0-rmse:1.75489
# [410]	validation_0-rmse:1.75755
# [411]	validation_0-rmse:1.75842
# [412]	validation_0-rmse:1.75959
# [413]	validation_0-rmse:1.75973
# [414]	validation_0-rmse:1.75881
# [415]	validation_0-rmse:1.75684
# [416]	validation_0-rmse:1.75782
# [417]	validation_0-rmse:1.75657
# [418]	validation_0-rmse:1.75451
# [419]	validation_0-rmse:1.75599
# [420]	validation_0-rmse:1.75584
# [421]	validation_0-rmse:1.75530
# [422]	validation_0-rmse:1.75771
# [423]	validation_0-rmse:1.76041
# [424]	validation_0-rmse:1.76150
# [425]	validation_0-rmse:1.76480
# [426]	validation_0-rmse:1.76548
# [427]	validation_0-rmse:1.76343
# [428]	validation_0-rmse:1.76528
# [429]	validation_0-rmse:1.76642
# [430]	validation_0-rmse:1.76602
# [431]	validation_0-rmse:1.76353
# [432]	validation_0-rmse:1.76157
# [433]	validation_0-rmse:1.75969
# [434]	validation_0-rmse:1.75984
# [435]	validation_0-rmse:1.75987
# [436]	validation_0-rmse:1.76199
# [437]	validation_0-rmse:1.76070
# [438]	validation_0-rmse:1.76262
# [439]	validation_0-rmse:1.76044
# [440]	validation_0-rmse:1.75859
# [441]	validation_0-rmse:1.76046
# [442]	validation_0-rmse:1.75905
# [443]	validation_0-rmse:1.75902
# [444]	validation_0-rmse:1.75175
# [445]	validation_0-rmse:1.75068
# [446]	validation_0-rmse:1.75055
# [447]	validation_0-rmse:1.74132
# [448]	validation_0-rmse:1.74398
# [449]	validation_0-rmse:1.74215
# [450]	validation_0-rmse:1.74325
# [451]	validation_0-rmse:1.73968
# [452]	validation_0-rmse:1.73779
# [453]	validation_0-rmse:1.73675
# [454]	validation_0-rmse:1.73551
# [455]	validation_0-rmse:1.73863
# [456]	validation_0-rmse:1.74006
# [457]	validation_0-rmse:1.74216
# [458]	validation_0-rmse:1.74017
# [459]	validation_0-rmse:1.73952
# [460]	validation_0-rmse:1.73661
# [461]	validation_0-rmse:1.73912
# [462]	validation_0-rmse:1.74289
# [463]	validation_0-rmse:1.74224
# [464]	validation_0-rmse:1.74118
# [465]	validation_0-rmse:1.74199
# [466]	validation_0-rmse:1.74555
# [467]	validation_0-rmse:1.74318
# [468]	validation_0-rmse:1.74406
# [469]	validation_0-rmse:1.74434
# [470]	validation_0-rmse:1.74882
# [471]	validation_0-rmse:1.75082
# [472]	validation_0-rmse:1.75094
# [473]	validation_0-rmse:1.75116
# [474]	validation_0-rmse:1.75114
# [475]	validation_0-rmse:1.74084
# [476]	validation_0-rmse:1.74068
# [477]	validation_0-rmse:1.73973
# [478]	validation_0-rmse:1.73845
# [479]	validation_0-rmse:1.73957
# [480]	validation_0-rmse:1.73923
# [481]	validation_0-rmse:1.73222
# [482]	validation_0-rmse:1.73172
# [483]	validation_0-rmse:1.73270
# [484]	validation_0-rmse:1.73385
# [485]	validation_0-rmse:1.73310
# [486]	validation_0-rmse:1.73563
# [487]	validation_0-rmse:1.73763
# [488]	validation_0-rmse:1.73539
# [489]	validation_0-rmse:1.73366
# [490]	validation_0-rmse:1.73410
# [491]	validation_0-rmse:1.73447
# [492]	validation_0-rmse:1.73482
# [493]	validation_0-rmse:1.73592
# [494]	validation_0-rmse:1.73691
# [495]	validation_0-rmse:1.73718
# [496]	validation_0-rmse:1.73742
# [497]	validation_0-rmse:1.73635
# [498]	validation_0-rmse:1.73657
# [499]	validation_0-rmse:1.73829
# [500]	validation_0-rmse:1.73805
# [501]	validation_0-rmse:1.73693
# [502]	validation_0-rmse:1.73355
# [503]	validation_0-rmse:1.73620
# [504]	validation_0-rmse:1.73702
# [505]	validation_0-rmse:1.73616
# [506]	validation_0-rmse:1.73806
# [507]	validation_0-rmse:1.73630
# [508]	validation_0-rmse:1.73622
# [509]	validation_0-rmse:1.73546
# [510]	validation_0-rmse:1.73405
# [511]	validation_0-rmse:1.73104
# [512]	validation_0-rmse:1.72936
# [513]	validation_0-rmse:1.73112
# [514]	validation_0-rmse:1.73029
# [515]	validation_0-rmse:1.73113
# [516]	validation_0-rmse:1.72952
# [517]	validation_0-rmse:1.72909
# [518]	validation_0-rmse:1.72782
# [519]	validation_0-rmse:1.73020
# [520]	validation_0-rmse:1.73010
# [521]	validation_0-rmse:1.72955
# [522]	validation_0-rmse:1.72915
# [523]	validation_0-rmse:1.72867
# [524]	validation_0-rmse:1.72625
# [525]	validation_0-rmse:1.72658
# [526]	validation_0-rmse:1.72556
# [527]	validation_0-rmse:1.72552
# [528]	validation_0-rmse:1.72713
# [529]	validation_0-rmse:1.72781
# [530]	validation_0-rmse:1.72729
# [531]	validation_0-rmse:1.72737
# [532]	validation_0-rmse:1.72772
# [533]	validation_0-rmse:1.72791
# [534]	validation_0-rmse:1.73233
# [535]	validation_0-rmse:1.73223
# [536]	validation_0-rmse:1.73325
# [537]	validation_0-rmse:1.73436
# [538]	validation_0-rmse:1.73667
# [539]	validation_0-rmse:1.73482
# [540]	validation_0-rmse:1.73467
# [541]	validation_0-rmse:1.73629
# [542]	validation_0-rmse:1.73703
# [543]	validation_0-rmse:1.73673
# [544]	validation_0-rmse:1.73482
# [545]	validation_0-rmse:1.73546
# [546]	validation_0-rmse:1.73697
# [547]	validation_0-rmse:1.73702
# [548]	validation_0-rmse:1.73342
# [549]	validation_0-rmse:1.73601
# [550]	validation_0-rmse:1.73718
# [551]	validation_0-rmse:1.73878
# [552]	validation_0-rmse:1.73903
# [553]	validation_0-rmse:1.73675
# [554]	validation_0-rmse:1.73595
# [555]	validation_0-rmse:1.73312
# [556]	validation_0-rmse:1.73305
# [557]	validation_0-rmse:1.73358
# [558]	validation_0-rmse:1.73271
# [559]	validation_0-rmse:1.73284
# [560]	validation_0-rmse:1.73394
# [561]	validation_0-rmse:1.73443
# [562]	validation_0-rmse:1.73570
# [563]	validation_0-rmse:1.73217
# [564]	validation_0-rmse:1.73283
# [565]	validation_0-rmse:1.73497
# [566]	validation_0-rmse:1.73515
# [567]	validation_0-rmse:1.74008
# [568]	validation_0-rmse:1.74244
# [569]	validation_0-rmse:1.74307
# [570]	validation_0-rmse:1.74452
# [571]	validation_0-rmse:1.74332
# [572]	validation_0-rmse:1.74193
# [573]	validation_0-rmse:1.73963
# [574]	validation_0-rmse:1.74343
# [575]	validation_0-rmse:1.74506
# [576]	validation_0-rmse:1.74523
# [577]	validation_0-rmse:1.74493
# [578]	validation_0-rmse:1.74487
# [579]	validation_0-rmse:1.74725
# [580]	validation_0-rmse:1.74684
# [581]	validation_0-rmse:1.74776
# [582]	validation_0-rmse:1.74729
# [583]	validation_0-rmse:1.74752
# [584]	validation_0-rmse:1.74660
# [585]	validation_0-rmse:1.75153
# [586]	validation_0-rmse:1.74916
# [587]	validation_0-rmse:1.75132
# [588]	validation_0-rmse:1.75296
# [589]	validation_0-rmse:1.75455
# [590]	validation_0-rmse:1.75845
# [591]	validation_0-rmse:1.74830
# [592]	validation_0-rmse:1.74908
# [593]	validation_0-rmse:1.74911
# [594]	validation_0-rmse:1.75028
# [595]	validation_0-rmse:1.74954
# [596]	validation_0-rmse:1.74872
# [597]	validation_0-rmse:1.74754
# [598]	validation_0-rmse:1.74772
# [599]	validation_0-rmse:1.74569
# [600]	validation_0-rmse:1.74468
# [601]	validation_0-rmse:1.74456
# [602]	validation_0-rmse:1.74292
# [603]	validation_0-rmse:1.74384
# [604]	validation_0-rmse:1.74252
# [605]	validation_0-rmse:1.74442
# [606]	validation_0-rmse:1.74472
# [607]	validation_0-rmse:1.74403
# [608]	validation_0-rmse:1.74235
# [609]	validation_0-rmse:1.74123
# [610]	validation_0-rmse:1.74106
# [611]	validation_0-rmse:1.74193
# [612]	validation_0-rmse:1.74093
# [613]	validation_0-rmse:1.74498
# [614]	validation_0-rmse:1.74540
# [615]	validation_0-rmse:1.74541
# [616]	validation_0-rmse:1.74284
# [617]	validation_0-rmse:1.73938
# [618]	validation_0-rmse:1.74032
# [619]	validation_0-rmse:1.74457
# [620]	validation_0-rmse:1.74523
# [621]	validation_0-rmse:1.74461
# [622]	validation_0-rmse:1.74520
# [623]	validation_0-rmse:1.74405
# [624]	validation_0-rmse:1.74467
# [625]	validation_0-rmse:1.74529
# [626]	validation_0-rmse:1.74747
# [627]	validation_0-rmse:1.74706
# [628]	validation_0-rmse:1.74555
# [629]	validation_0-rmse:1.74479
# [630]	validation_0-rmse:1.74545
# [631]	validation_0-rmse:1.74690
# [632]	validation_0-rmse:1.74650
# [633]	validation_0-rmse:1.74623
# [634]	validation_0-rmse:1.74821
# [635]	validation_0-rmse:1.74352
# [636]	validation_0-rmse:1.74209
# [637]	validation_0-rmse:1.74156
# [638]	validation_0-rmse:1.74061
# [639]	validation_0-rmse:1.74040
# [640]	validation_0-rmse:1.74062
# [641]	validation_0-rmse:1.74013
# [642]	validation_0-rmse:1.73619
# [643]	validation_0-rmse:1.73935
# [644]	validation_0-rmse:1.74046
# [645]	validation_0-rmse:1.73992
# [646]	validation_0-rmse:1.73909
# [647]	validation_0-rmse:1.74061
# [648]	validation_0-rmse:1.74537
# [649]	validation_0-rmse:1.74892
# [650]	validation_0-rmse:1.74557
# [651]	validation_0-rmse:1.74403
# [652]	validation_0-rmse:1.74724
# [653]	validation_0-rmse:1.74908
# [654]	validation_0-rmse:1.74839
# [655]	validation_0-rmse:1.75039
# [656]	validation_0-rmse:1.74938
# [657]	validation_0-rmse:1.74917
# [658]	validation_0-rmse:1.74822
# [659]	validation_0-rmse:1.74826
# [660]	validation_0-rmse:1.74947
# [661]	validation_0-rmse:1.74919
# [662]	validation_0-rmse:1.74844
# [663]	validation_0-rmse:1.74817
# [664]	validation_0-rmse:1.74875
# [665]	validation_0-rmse:1.74899
# [666]	validation_0-rmse:1.74785
# [667]	validation_0-rmse:1.74829
# [668]	validation_0-rmse:1.74406
# [669]	validation_0-rmse:1.74390
# [670]	validation_0-rmse:1.74649
# [671]	validation_0-rmse:1.74528
# [672]	validation_0-rmse:1.74519
# [673]	validation_0-rmse:1.74686
# [674]	validation_0-rmse:1.74719
# [675]	validation_0-rmse:1.74560
# [676]	validation_0-rmse:1.74468
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.3,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=300,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, ...)

# %%
from sklearn.metrics import r2_score
y_predict = model.predict(x_valid)
r2_score(y_valid, y_predict)
# Out:
# 0.6118918477229789
