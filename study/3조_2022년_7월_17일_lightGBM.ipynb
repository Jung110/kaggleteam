# %%
# 사용할 모듈 불러오기 
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import re

# %%
# 데이터 불러오기
items = pd.read_csv("./data/items.csv")
shops = pd.read_csv("./data/shops.csv")
train = pd.read_csv("./data/sales_train.csv")
test = pd.read_csv("./data/test.csv")
item_categories = pd.read_csv('./data/item_categories.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Train
# ###  columns 뜻
#  - data  = 날짜
#  - date_block_num  = 한달 단위로 구분하기 편하게 하기 위한 데이터
#  - shop_id = 가게 id
#  - item_price = 아이템 가격
#  - item_cnt_day = 당일 해당 아이템이 팔린 개수

# %%
train.info() # null 값이 모든데이터에 존재 하지 않는다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
#  date의 자료형을 object  -> dattime 으로 바꾸고 싶다. 
# 변환하는 과정  ->
train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")
train["date"]. head(3)
# Out:
# 0   2013-01-02
# 1   2013-01-03
# 2   2013-01-05
# Name: date, dtype: datetime64[ns]

# %%
train.describe(include = 'all')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17432\2740853986.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   train.describe(include = 'all')
#                        date  date_block_num       shop_id       item_id  \
# count               2935849    2.935849e+06  2.935849e+06  2.935849e+06
# unique                 1034             NaN           NaN           NaN
# top     2013-12-28 00:00:00             NaN           NaN           NaN
# freq                   9434             NaN           NaN           NaN
# first   2013-01-01 00:00:00             NaN           NaN           NaN
# last    2015-10-31 00:00:00             NaN           NaN           NaN
# mean                    NaN    1.456991e+01  3.300173e+01  1.019723e+04
# std                     NaN    9.422988e+00  1.622697e+01  6.324297e+03
# min                     NaN    0.000000e+00  0.000000e+00  0.000000e+00
# 25%                     NaN    7.000000e+00  2.200000e+01  4.476000e+03
# 50%                     NaN    1.400000e+01  3.100000e+01  9.343000e+03
# 75%                     NaN    2.300000e+01  4.700000e+01  1.568400e+04
# max                     NaN    3.300000e+01  5.900000e+01  2.216900e+04
#
#           item_price  item_cnt_day
# count   2.935849e+06  2.935849e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    8.908532e+02  1.242641e+00
# std     1.729800e+03  2.618834e+00
# min    -1.000000e+00 -2.200000e+01
# 25%     2.490000e+02  1.000000e+00
# 50%     3.990000e+02  1.000000e+00
# 75%     9.990000e+02  1.000000e+00
# max     3.079800e+05  2.169000e+03

# %% [markdown]
# 2013-01-01 00:00:00 ~ 2015-10-31 00:00:00  까지의 1034일간의 데이터임을 알수있다.
# item_price은 평균과 중위값의 차이가 심한 것으로 보아 이상치가 존재함을 알 수 있디.
# item_cnt_day 는일,이,삼 분위수가 1인데 비해 평균은 대략 1.2  최대값은 2168로 이상치가 존재한다.
# item_cnt_day, item_price에 최소값들은 음수이다.

# %%
def price_item_cnt_day_boxplot():
    plt.figure(figsize = (20,10))
    # item_price 의 박스플롯
    plt.subplot(1,2,1)
    sns.boxplot(x = 'date_block_num' , y= 'item_price',data =train)
    plt.title('item_price')
    plt.grid()
    # item_cnt_day의 박스 플롯
    plt.subplot(1,2,2)
    sns.boxplot(x = 'date_block_num' , y= 'item_cnt_day',data =train)
    plt.title('item_cnt_day')
    plt.grid()
price_item_cnt_day_boxplot()

# %% [markdown]
# - 다음은 date_block_num 별로 item_price의 boxplot이다.
# - 위의 그래프를 기준으로 item_price는 50000 이상 , item_cnt_day 는 1000 이상을 이상치로서 train에서 제거한다.
# - 또한 판매되는 수량을 구하는 것이 목적이므로 0미만의 값을 제거한다.

# %%
condition_for_drop = ((train["item_price"] >= 50000) | (train["item_price"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

condition_for_drop = ((train["item_cnt_day"] >= 1000) | (train["item_cnt_day"] < 0))
train.drop(train[condition_for_drop].index, axis = 0 , inplace=True)

# %%
# 제거 후의 boxplot
price_item_cnt_day_boxplot()

# %%
train.corr()
# Out:
#                 date_block_num   shop_id   item_id  item_price  item_cnt_day
# date_block_num        1.000000  0.019329  0.009472    0.095539      0.010339
# shop_id               0.019329  1.000000  0.029345   -0.023955     -0.005660
# item_id               0.009472  0.029345  1.000000   -0.134812      0.018896
# item_price            0.095539 -0.023955 -0.134812    1.000000      0.014444
# item_cnt_day          0.010339 -0.005660  0.018896    0.014444      1.000000

# %% [markdown]
# ## shops

# %%
shops.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
shops.head(20)
# Out:
#                          shop_name  shop_id
# 0    !Якутск Орджоникидзе, 56 фран        0
# 1    !Якутск ТЦ "Центральный" фран        1
# 2                 Адыгея ТЦ "Мега"        2
# 3   Балашиха ТРК "Октябрь-Киномир"        3
# 4         Волжский ТЦ "Волга Молл"        4
# 5           Вологда ТРЦ "Мармелад"        5
# 6       Воронеж (Плехановская, 13)        6
# 7           Воронеж ТРЦ "Максимир"        7
# 8     Воронеж ТРЦ Сити-Парк "Град"        8
# 9                Выездная Торговля        9
# 10      Жуковский ул. Чкалова 39м?       10
# 11      Жуковский ул. Чкалова 39м²       11
# 12             Интернет-магазин ЧС       12
# 13             Казань ТЦ "Бехетле"       13
# 14         Казань ТЦ "ПаркХаус" II       14
# 15            Калуга ТРЦ "XXI век"       15
# 16                Коломна ТЦ "Рио"       16
# 17   Красноярск ТЦ "Взлетка Плаза"       17
# 18            Красноярск ТЦ "Июнь"       18
# 19           Курск ТЦ "Пушкинский"       19

# %% [markdown]
# - 이름에 특수문자가 들어가고 중복되는 이름들이 보인다

# %%
def clean_text(inputString):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
    return text_rmv
shops_names = shops["shop_name"].apply(clean_text)
shops_id = shops["shop_id"]
# 중복되는 이름 확인 
for i in list(zip(shops_names ,shops_id)):
    for j in list(zip(shops_names ,shops_id)):
        if (re.match('.*'+i[0]+'*.',j[0])) and (i[1]!= j[1]):
            print('code : ', i[1], ' and  ', j[1])
            print('name : ', i[0], ' and  ', j[0])
# Out:
# code :  10  and   11
# name :  Жуковский ул  Чкалова 39м   and   Жуковский ул  Чкалова 39м²
# code :  11  and   10
# name :  Жуковский ул  Чкалова 39м²  and   Жуковский ул  Чкалова 39м
# code :  39  and   40
# name :  РостовНаДону ТРК  Мегацентр Горизонт   and   РостовНаДону ТРК  Мегацентр Горизонт  Островной
# code :  57  and   0
# name :  Якутск Орджоникидзе  56  and    Якутск Орджоникидзе  56 фран
# code :  58  and   1
# name :  Якутск ТЦ  Центральный   and    Якутск ТЦ  Центральный  фран

# %% [markdown]
# - 위와 같이 shop id가 10:11, 39:40, 57:0, 58:1 4개의 아이디가 중복되는 것을 알 수 있다.
# - 위의 데이터를 기준으로 train data의 shop id를 바꾸어준다

# %%
train["shop_id"] = train["shop_id"].replace({0: 57, 1: 58, 11: 10, 40: 39})

# %% [markdown]
# ## items

# %%
items.info() # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items.head(20) # 이름에 특수 문자 제거 후 비슷한 게임끼리
# Out:
#                                             item_name  item_id  \
# 0           ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1   !ABBYY FineReader 12 Professional Edition Full...        1
# 2       ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3     ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4         ***КОРОБКА (СТЕКЛО)                       D        4
# 5   ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6            ***УДАР ПО ВОРОТАМ (UNI)               D        6
# 7          ***УДАР ПО ВОРОТАМ-2 (UNI)               D        7
# 8            ***ЧАЙ С МУССОЛИНИ                     D        8
# 9       ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D        9
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D       10
# 11          *ЛИНИЯ СМЕРТИ                           D       11
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12
# 13          *СПАСАЯ ЭМИЛИ                           D       13
# 14          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D       14
# 15             //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ (Регион)       15
# 16                         //МОНГОЛ С.Бодров (Регион)       16
# 17                    //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА (Регион)       17
# 18          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D       18
# 19                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72       19
#
#     item_category_id
# 0                 40
# 1                 76
# 2                 40
# 3                 40
# 4                 40
# 5                 40
# 6                 40
# 7                 40
# 8                 40
# 9                 40
# 10                40
# 11                40
# 12                55
# 13                40
# 14                40
# 15                40
# 16                40
# 17                40
# 18                40
# 19                40

# %%
plt.figure(figsize=(20,10))
sns.countplot(x= 'item_category_id' , data = items)
plt.xticks(size = 15 , rotation =  45 , color = 'black')
plt.show()

# %%
item_categories[item_categories['item_category_id']==40]
# Out:
#    item_category_name  item_category_id
# 40         Кино - DVD                40

# %% [markdown]
# - item_category_id =40 인  Кино - DVD 카테고리에 많은 아이템이 존재하는지 알 수 있다

# %% [markdown]
# ## item_category

# %%
item_categories.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories.head(20)
# Out:
#             item_category_name  item_category_id
# 0      PC - Гарнитуры/Наушники                 0
# 1             Аксессуары - PS2                 1
# 2             Аксессуары - PS3                 2
# 3             Аксессуары - PS4                 3
# 4             Аксессуары - PSP                 4
# 5          Аксессуары - PSVita                 5
# 6        Аксессуары - XBOX 360                 6
# 7        Аксессуары - XBOX ONE                 7
# 8               Билеты (Цифра)                 8
# 9              Доставка товара                 9
# 10       Игровые консоли - PS2                10
# 11       Игровые консоли - PS3                11
# 12       Игровые консоли - PS4                12
# 13       Игровые консоли - PSP                13
# 14    Игровые консоли - PSVita                14
# 15  Игровые консоли - XBOX 360                15
# 16  Игровые консоли - XBOX ONE                16
# 17    Игровые консоли - Прочие                17
# 18                  Игры - PS2                18
# 19                  Игры - PS3                19

# %% [markdown]
# - item_category_name에 같은 단어가 들어가는 데이터가 많이 존재한다
# - 이를 묶어 더 큰 범주를 만들 수 있다.

# %% [markdown]
# ## test

# %%
test.info()  # 결측값은 없고 데이터 타입이 적당함을 알수있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB

# %%
# test의 shop_id , item_id 기 train 데이터에 있는지 확인
diff_test_train_shop_id  = set(test['shop_id']) - set(train['shop_id'])
print('diffrent shop_id nums: ',len(diff_test_train_shop_id))
diff_test_train_item_id = set(test['item_id']) - set(train['item_id'])
print('diffrent item_id nums: ',len(diff_test_train_item_id))
diff_test_items_item_id = set(test['item_id']) - set(items['item_id'])
print('diff_test_items_itemid nums: ',len(diff_test_items_item_id))
# Out:
# diffrent shop_id nums:  0
# diffrent item_id nums:  363
# diff_test_items_itemid nums:  0

# %% [markdown]
# #### test에는 존재하지만 train에 존재하지 않는 값이 363개 존재한다.
# #### items에는 test에 있는 모든 item_id를 가지고 있다.
# #### 이를 해결하기위해 다음과 같은 방법을 사용한다
#  - train에 존재하지 않는 test값을 예측하기 위해 item_category_id를 사용한다.

# %% [markdown]
# ## high_category

# %% [markdown]
# item_category의 앞부분만 자르고 새롭게 만든 열을 라벨인코딩 (악세사리 >> 1)
# item_id와 연결되어있는 item_category를 새롭게 만든 열로 연결하여 test값을 예측한다면?

# %%
# item_category 분류하여 새로운 열 만들기
def make_high_category(data_name_col):
    '''
    상위 분류를 생성후 라벨 인코딩을 하는 함수
    shopname 과 item_category_name 에 사용
    '''
    data_name_col
    data_name_col = data_name_col.apply(clean_text)
    high_category_name = data_name_col.str.split(' ')
    high_category_name = [data[1] if data[0] == '' else data[0] for data in high_category_name]
    high_category_name_le = LabelEncoder()
    high_category_name_le.fit(high_category_name)
    high_category_id = high_category_name_le.transform(high_category_name)
    return high_category_name , high_category_id

# %%
item_categories['high_category_name'] , item_categories['high_category_id'] =\
make_high_category(item_categories.item_category_name)

# %%
item_categories.head(3)
# Out:
#         item_category_name  item_category_id high_category_name  \
# 0  PC - Гарнитуры/Наушники                 0                 PC
# 1         Аксессуары - PS2                 1         Аксессуары
# 2         Аксессуары - PS3                 2         Аксессуары
#
#    high_category_id
# 0                 0
# 1                 1
# 2                 1

# %%
shops['city_name'],shops['city_id'] = make_high_category(shops.shop_name)

# %%
shops.head(3)
# Out:
#                        shop_name  shop_id city_name  city_id
# 0  !Якутск Орджоникидзе, 56 фран        0    Якутск       29
# 1  !Якутск ТЦ "Центральный" фран        1    Якутск       29
# 2               Адыгея ТЦ "Мега"        2    Адыгея        0

# %% [markdown]
# ## train + test

# %%
'''
test에 없는 열을 추가 해야 하거나
train에 쓸모없는 데이터를 제거해야 한다. 
'''
test.columns , train.columns
# Out:
# (Index(['ID', 'shop_id', 'item_id'], dtype='object'),
#  Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#         'item_cnt_day'],
#        dtype='object'))

# %%
test['date_block_num'] = 34
test['item_price'] = 1
test['item_cnt_day'] = 0
del train['date']
del test['ID']

# %%
test.columns , train.columns
# Out:
# (Index(['shop_id', 'item_id', 'date_block_num', 'item_price', 'item_cnt_day'], dtype='object'),
#  Index(['date_block_num', 'shop_id', 'item_id', 'item_price', 'item_cnt_day'], dtype='object'))

# %%
# 인덱스 값이 꼬여있다.
pd.concat([test,train])
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0              5     5037              34         1.0           0.0
# 1              5     5320              34         1.0           0.0
# 2              5     5233              34         1.0           0.0
# 3              5     5232              34         1.0           0.0
# 4              5     5268              34         1.0           0.0
# ...          ...      ...             ...         ...           ...
# 2935844       25     7409              33       299.0           1.0
# 2935845       25     7460              33       299.0           1.0
# 2935846       25     7459              33       349.0           1.0
# 2935847       25     7440              33       299.0           1.0
# 2935848       25     7460              33       299.0           1.0
#
# [3142687 rows x 5 columns]

# %%
pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)
# Out:
#          shop_id  item_id  date_block_num  item_price  item_cnt_day
# 0             16    18336               0       299.0           1.0
# 1             25    18631               0       149.0           1.0
# 2             25    19333               0       350.0           1.0
# 3             25    19330               0       349.0           1.0
# 4             25    18546               0       149.0           1.0
# ...          ...      ...             ...         ...           ...
# 3142682       57    18454              34         1.0           0.0
# 3142683       57    18027              34         1.0           0.0
# 3142684       57    18049              34         1.0           0.0
# 3142685       57    18589              34         1.0           0.0
# 3142686        5     5037              34         1.0           0.0
#
# [3142687 rows x 5 columns]

# %%
sales_df = pd.concat([test,train]).sort_values('date_block_num').reset_index().drop('index',axis = 1)

# %%
sales_df = pd.merge(sales_df ,shops ,on =  'shop_id').drop(['shop_name','city_name'] ,axis =1)

# %%
sales_df.head(3)
# Out:
#    shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id
# 0       16    18336               0       299.0           1.0       10
# 1       16    21347               0       549.0           1.0       10
# 2       16    20890               0      1899.0           1.0       10

# %%
item_high_categories = items.merge(item_categories).drop(['item_name','item_category_name','high_category_name'],axis = 1)
item_high_categories.head(3)
# Out:
#    item_id  item_category_id  high_category_id
# 0        0                40                 7
# 1        2                40                 7
# 2        3                40                 7

# %%
sales_df = pd.merge(sales_df ,item_high_categories ,on =  'item_id')

# %%
sales_df['item_revenue_day'] = sales_df.item_cnt_day * sales_df.item_price

# %%
sales_df.head(3)
# Out:
#    shop_id  item_id  date_block_num  item_price  item_cnt_day  city_id  \
# 0       16    18336               0       299.0           1.0       10
# 1       25    18336               0       299.0           1.0       13
# 2       25    18336               1       299.0           1.0       13
#
#    item_category_id  high_category_id  item_revenue_day
# 0                57                 9             299.0
# 1                57                 9             299.0
# 2                57                 9             299.0

# %%
base_item_feature_names = ['item_id','item_category_id','high_category_id']
base_place_feature_names = ['shop_id','city_id']
mean_feature_names = ['item_cnt_day','item_revenue_day']

# %%
def add_mean_feature(df , base_feature_names ,mean_feature_names):
    '''
    base_feature_name를 기준으로 mean_feature_names의 값들을 
    한달 평균을 구해서 df에 병합해주는 함수
    '''
    df_pivot  = df[list(base_feature_names) + list(mean_feature_names)]
    col_name = ''
    for base_feature_name in base_feature_names:
        if base_feature_name !='date_block_num':
            col_name += '_'.join(base_feature_name.split('_')[:-1])+'_'

    for mean_feature_name in mean_feature_names:
        df_pivot = df_pivot.rename(columns = {mean_feature_name:col_name + mean_feature_name.split('_')[1]+'_month_mean'})

    df_pivot = df_pivot.pivot_table(index = base_feature_names)
    df = df.merge(df_pivot , on =base_feature_names)
    return df

# %%
for place in base_place_feature_names:
    for item in base_item_feature_names:
        base_feature_names = ['date_block_num', place,item]
        sales_df = add_mean_feature(sales_df ,base_feature_names,mean_feature_names)

# %%
sales_df.columns
# Out:
# Index(['shop_id', 'item_id', 'date_block_num', 'item_price', 'item_cnt_day',
#        'city_id', 'item_category_id', 'high_category_id', 'item_revenue_day',
#        'shop_item_cnt_month_mean', 'shop_item_revenue_month_mean',
#        'shop_item_category_cnt_month_mean',
#        'shop_item_category_revenue_month_mean',
#        'shop_high_category_cnt_month_mean',
#        'shop_high_category_revenue_month_mean', 'city_item_cnt_month_mean',
#        'city_item_revenue_month_mean', 'city_item_category_cnt_month_mean',
#        'city_item_category_revenue_month_mean',
#        'city_high_category_cnt_month_mean',
#        'city_high_category_revenue_month_mean'],
#       dtype='object')

# %% [markdown]
# # drop uslessID

# %%
sales_df.drop(base_item_feature_names+base_place_feature_names , axis =1  , inplace = True)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(sales_df.corr() , annot=True)
plt.show()

# %% [markdown]
# # Holdsout

# %%
x_train = sales_df[sales_df['date_block_num'] < 33]
x_train = x_train.drop(['item_cnt_day'], axis = 1)
y_train = sales_df[sales_df['date_block_num'] < 33]['item_cnt_day']


x_valid = sales_df[sales_df['date_block_num'] == 33]
x_valid = x_valid.drop(['item_cnt_day'], axis = 1)
y_valid = sales_df[sales_df['date_block_num'] == 33]['item_cnt_day']

x_test = sales_df[sales_df['date_block_num'] == 34]
x_test = x_test.drop(['item_cnt_day'], axis = 1)
y_test = sales_df[sales_df['date_block_num'] == 34]['item_cnt_day']

# %% [markdown]
# ## LGBM연습

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_log_error
import os

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['l1','l2'],
    'learning_rate': 0.005,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'verbose': 0,
    "max_depth": 8,
    "num_leaves": 128,  
    "max_bin": 512,
    "num_iterations": 100000
}

# %%
gbm = lgb.LGBMRegressor(**hyper_params)

# %%
gbm.fit(x_train, y_train,
        eval_set=[(x_valid, y_valid)],
        eval_metric='l1',
        early_stopping_rounds=1000)
# Out:
# c:\Users\user\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\user\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024929 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [1]	valid_0's l1: 0.485438	valid_0's l2: 7.65005
# [2]	valid_0's l1: 0.483298	valid_0's l2: 7.61254
# [3]	valid_0's l1: 0.481146	valid_0's l2: 7.57527
# [4]	valid_0's l1: 0.479024	valid_0's l2: 7.53845
# [5]	valid_0's l1: 0.476909	valid_0's l2: 7.50185
# [6]	valid_0's l1: 0.474802	valid_0's l2: 7.46574
# [7]	valid_0's l1: 0.472698	valid_0's l2: 7.42973
# [8]	valid_0's l1: 0.470604	valid_0's l2: 7.39409
# [9]	valid_0's l1: 0.468525	valid_0's l2: 7.35875
# [10]	valid_0's l1: 0.46646	valid_0's l2: 7.32378
# [11]	valid_0's l1: 0.464446	valid_0's l2: 7.29397
# [12]	valid_0's l1: 0.462439	valid_0's l2: 7.26427
# [13]	valid_0's l1: 0.460449	valid_0's l2: 7.23498
# [14]	valid_0's l1: 0.458438	valid_0's l2: 7.20423
# [15]	valid_0's l1: 0.456466	valid_0's l2: 7.17421
# [16]	valid_0's l1: 0.454447	valid_0's l2: 7.13956
# [17]	valid_0's l1: 0.452488	valid_0's l2: 7.10901
# [18]	valid_0's l1: 0.450534	valid_0's l2: 7.0795
# [19]	valid_0's l1: 0.448572	valid_0's l2: 7.04288
# [20]	valid_0's l1: 0.446572	valid_0's l2: 7.00723
# [21]	valid_0's l1: 0.444638	valid_0's l2: 6.97894
# [22]	valid_0's l1: 0.442714	valid_0's l2: 6.95069
# [23]	valid_0's l1: 0.440835	valid_0's l2: 6.92421
# [24]	valid_0's l1: 0.438961	valid_0's l2: 6.89652
# [25]	valid_0's l1: 0.437113	valid_0's l2: 6.86926
# [26]	valid_0's l1: 0.43526	valid_0's l2: 6.84213
# [27]	valid_0's l1: 0.433436	valid_0's l2: 6.80947
# [28]	valid_0's l1: 0.431542	valid_0's l2: 6.77901
# [29]	valid_0's l1: 0.429698	valid_0's l2: 6.75235
# [30]	valid_0's l1: 0.427865	valid_0's l2: 6.72238
# [31]	valid_0's l1: 0.425997	valid_0's l2: 6.69571
# [32]	valid_0's l1: 0.424163	valid_0's l2: 6.66292
# [33]	valid_0's l1: 0.422318	valid_0's l2: 6.63669
# [34]	valid_0's l1: 0.420503	valid_0's l2: 6.61085
# [35]	valid_0's l1: 0.418719	valid_0's l2: 6.58561
# [36]	valid_0's l1: 0.417406	valid_0's l2: 6.56846
# [37]	valid_0's l1: 0.415598	valid_0's l2: 6.54368

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's l1: 0.135175	valid_0's l2: 2.59558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's l1: 0.134695	valid_0's l2: 2.59028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's l1: 0.134197	valid_0's l2: 2.58517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's l1: 0.133729	valid_0's l2: 2.58011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's l1: 0.133256	valid_0's l2: 2.57494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's l1: 0.132795	valid_0's l2: 2.56983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's l1: 0.132331	valid_0's l2: 2.56478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's l1: 0.131872	valid_0's l2: 2.55974
# [331]	valid_0's l1: 0.131594	valid_0's l2: 2.55672
# [332]	valid_0's l1: 0.131117	valid_0's l2: 2.54995
# [333]	valid_0's l1: 0.130645	valid_0's l2: 2.54327
# [334]	valid_0's l1: 0.130373	valid_0's l2: 2.54029
# [335]	valid_0's l1: 0.129937	valid_0's l2: 2.53361
# [336]	valid_0's l1: 0.129475	valid_0's l2: 2.52706
# [337]	valid_0's l1: 0.12921	valid_0's l2: 2.52413
# [338]	valid_0's l1: 0.128744	valid_0's l2: 2.51757
# [339]	valid_0's l1: 0.128481	valid_0's l2: 2.51468
# [340]	valid_0's l1: 0.128044	valid_0's l2: 2.50821
# [341]	valid_0's l1: 0.127554	valid_0's l2: 2.50699
# [342]	valid_0's l1: 0.127071	valid_0's l2: 2.50578
# [343]	valid_0's l1: 0.126586	valid_0's l2: 2.5046
# [344]	valid_0's l1: 0.126107	valid_0's l2: 2.50336
# [345]	valid_0's l1: 0.125623	valid_0's l2: 2.50207
# [346]	valid_0's l1: 0.125152	valid_0's l2: 2.49637
# [347]	valid_0's l1: 0.124675	valid_0's l2: 2.49519
# [348]	valid_0's l1: 0.124443	valid_0's l2: 2.49399
# [349]	valid_0's l1: 0.123992	valid_0's l2: 2.4929
# [350]	valid_0's l1: 0.123586	valid_0's l2: 2.492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's l1: 0.123146	valid_0's l2: 2.48516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's l1: 0.122696	valid_0's l2: 2.47832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's l1: 0.122268	valid_0's l2: 2.47063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's l1: 0.121832	valid_0's l2: 2.4639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's l1: 0.121396	valid_0's l2: 2.4572
# [356]	valid_0's l1: 0.121171	valid_0's l2: 2.45418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's l1: 0.120744	valid_0's l2: 2.44758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's l1: 0.120321	valid_0's l2: 2.44102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's l1: 0.119888	valid_0's l2: 2.43446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's l1: 0.119462	valid_0's l2: 2.42798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's l1: 0.119075	valid_0's l2: 2.42285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's l1: 0.118661	valid_0's l2: 2.41984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's l1: 0.118252	valid_0's l2: 2.41686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's l1: 0.117872	valid_0's l2: 2.4118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's l1: 0.117457	valid_0's l2: 2.40653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's l1: 0.11705	valid_0's l2: 2.4036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's l1: 0.11668	valid_0's l2: 2.39869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's l1: 0.116273	valid_0's l2: 2.39352
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's l1: 0.115872	valid_0's l2: 2.39082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's l1: 0.115468	valid_0's l2: 2.38566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's l1: 0.115077	valid_0's l2: 2.38047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's l1: 0.11469	valid_0's l2: 2.37533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's l1: 0.114312	valid_0's l2: 2.37033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's l1: 0.113954	valid_0's l2: 2.36939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's l1: 0.113569	valid_0's l2: 2.36437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's l1: 0.113226	valid_0's l2: 2.36353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's l1: 0.112862	valid_0's l2: 2.35867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's l1: 0.11249	valid_0's l2: 2.35381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's l1: 0.112127	valid_0's l2: 2.34905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's l1: 0.111766	valid_0's l2: 2.34428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's l1: 0.111386	valid_0's l2: 2.33912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's l1: 0.111014	valid_0's l2: 2.33401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's l1: 0.110626	valid_0's l2: 2.32864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's l1: 0.110295	valid_0's l2: 2.3279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's l1: 0.109912	valid_0's l2: 2.32258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's l1: 0.10954	valid_0's l2: 2.31757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's l1: 0.109173	valid_0's l2: 2.31258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's l1: 0.108798	valid_0's l2: 2.30732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's l1: 0.108437	valid_0's l2: 2.30241
# [390]	valid_0's l1: 0.108244	valid_0's l2: 2.30033
# [391]	valid_0's l1: 0.108058	valid_0's l2: 2.30049
# [392]	valid_0's l1: 0.107873	valid_0's l2: 2.30065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's l1: 0.107529	valid_0's l2: 2.29658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's l1: 0.107181	valid_0's l2: 2.29239
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's l1: 0.106831	valid_0's l2: 2.28829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's l1: 0.106507	valid_0's l2: 2.28741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's l1: 0.106166	valid_0's l2: 2.28334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's l1: 0.105825	valid_0's l2: 2.27929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's l1: 0.105477	valid_0's l2: 2.27532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's l1: 0.105138	valid_0's l2: 2.27135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's l1: 0.104829	valid_0's l2: 2.26901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's l1: 0.104535	valid_0's l2: 2.26883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's l1: 0.104243	valid_0's l2: 2.26865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's l1: 0.103921	valid_0's l2: 2.26614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's l1: 0.103626	valid_0's l2: 2.26588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's l1: 0.103308	valid_0's l2: 2.26339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's l1: 0.102996	valid_0's l2: 2.26092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's l1: 0.102681	valid_0's l2: 2.25848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's l1: 0.102374	valid_0's l2: 2.25605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's l1: 0.102065	valid_0's l2: 2.25369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's l1: 0.101778	valid_0's l2: 2.25325
# [412]	valid_0's l1: 0.101411	valid_0's l2: 2.25302
# [413]	valid_0's l1: 0.101047	valid_0's l2: 2.25279
# [414]	valid_0's l1: 0.100686	valid_0's l2: 2.2526
# [415]	valid_0's l1: 0.100536	valid_0's l2: 2.25269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's l1: 0.100267	valid_0's l2: 2.25225
# [417]	valid_0's l1: 0.0999077	valid_0's l2: 2.25204
# [418]	valid_0's l1: 0.0995574	valid_0's l2: 2.25191
# [419]	valid_0's l1: 0.0992454	valid_0's l2: 2.25109
# [420]	valid_0's l1: 0.0989062	valid_0's l2: 2.25114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's l1: 0.0986069	valid_0's l2: 2.25103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's l1: 0.0983276	valid_0's l2: 2.25099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's l1: 0.0980386	valid_0's l2: 2.25092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's l1: 0.0977754	valid_0's l2: 2.25029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's l1: 0.0975159	valid_0's l2: 2.24974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's l1: 0.0972388	valid_0's l2: 2.24962
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's l1: 0.0969686	valid_0's l2: 2.24904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's l1: 0.0966874	valid_0's l2: 2.24905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's l1: 0.0964196	valid_0's l2: 2.24848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's l1: 0.0961312	valid_0's l2: 2.2483
# [431]	valid_0's l1: 0.0958567	valid_0's l2: 2.24451
# [432]	valid_0's l1: 0.0955749	valid_0's l2: 2.24068
# [433]	valid_0's l1: 0.0954319	valid_0's l2: 2.23923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's l1: 0.0951734	valid_0's l2: 2.23875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [487]	valid_0's l1: 0.082672	valid_0's l2: 2.10087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [488]	valid_0's l1: 0.0824558	valid_0's l2: 2.09815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's l1: 0.0822487	valid_0's l2: 2.09543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	valid_0's l1: 0.0820188	valid_0's l2: 2.09369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491]	valid_0's l1: 0.0818492	valid_0's l2: 2.08915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [492]	valid_0's l1: 0.0816302	valid_0's l2: 2.08417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	valid_0's l1: 0.0814477	valid_0's l2: 2.08389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [494]	valid_0's l1: 0.0812313	valid_0's l2: 2.07895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [495]	valid_0's l1: 0.0810464	valid_0's l2: 2.07867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [496]	valid_0's l1: 0.0808308	valid_0's l2: 2.07379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	valid_0's l1: 0.0806181	valid_0's l2: 2.06893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	valid_0's l1: 0.080401	valid_0's l2: 2.0641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	valid_0's l1: 0.0802027	valid_0's l2: 2.05931
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	valid_0's l1: 0.0800386	valid_0's l2: 2.05496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	valid_0's l1: 0.079874	valid_0's l2: 2.05507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	valid_0's l1: 0.0796789	valid_0's l2: 2.05525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	valid_0's l1: 0.079485	valid_0's l2: 2.05543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [504]	valid_0's l1: 0.0792927	valid_0's l2: 2.05561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [505]	valid_0's l1: 0.0791304	valid_0's l2: 2.05497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	valid_0's l1: 0.0789475	valid_0's l2: 2.05442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	valid_0's l1: 0.0787555	valid_0's l2: 2.05394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [508]	valid_0's l1: 0.0785714	valid_0's l2: 2.0534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [509]	valid_0's l1: 0.0783804	valid_0's l2: 2.05294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	valid_0's l1: 0.0782857	valid_0's l2: 2.05128
# [511]	valid_0's l1: 0.0781934	valid_0's l2: 2.04857
# [512]	valid_0's l1: 0.077997	valid_0's l2: 2.04489
# [513]	valid_0's l1: 0.0778029	valid_0's l2: 2.04123
# [514]	valid_0's l1: 0.0776085	valid_0's l2: 2.0376
# [515]	valid_0's l1: 0.0774095	valid_0's l2: 2.03399
# [516]	valid_0's l1: 0.0772207	valid_0's l2: 2.03041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [517]	valid_0's l1: 0.077061	valid_0's l2: 2.02706
# [518]	valid_0's l1: 0.0768646	valid_0's l2: 2.02349
# [519]	valid_0's l1: 0.076656	valid_0's l2: 2.01994
# [520]	valid_0's l1: 0.0764813	valid_0's l2: 2.01737
# [521]	valid_0's l1: 0.0762883	valid_0's l2: 2.01723
# [522]	valid_0's l1: 0.0760964	valid_0's l2: 2.01708
# [523]	valid_0's l1: 0.0758983	valid_0's l2: 2.01688
# [524]	valid_0's l1: 0.0757129	valid_0's l2: 2.01674
# [525]	valid_0's l1: 0.0755053	valid_0's l2: 2.01366
# [526]	valid_0's l1: 0.0753071	valid_0's l2: 2.01014
# [527]	valid_0's l1: 0.0751128	valid_0's l2: 2.00709
# [528]	valid_0's l1: 0.0749118	valid_0's l2: 2.00406
# [529]	valid_0's l1: 0.0747246	valid_0's l2: 2.00099
# [530]	valid_0's l1: 0.0745461	valid_0's l2: 1.99793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [531]	valid_0's l1: 0.0743806	valid_0's l2: 1.99515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	valid_0's l1: 0.074216	valid_0's l2: 1.99238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6304]	valid_0's l1: 0.0327757	valid_0's l2: 1.09901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6305]	valid_0's l1: 0.0327772	valid_0's l2: 1.09883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6306]	valid_0's l1: 0.0327775	valid_0's l2: 1.09865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6307]	valid_0's l1: 0.0327763	valid_0's l2: 1.09839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6308]	valid_0's l1: 0.032777	valid_0's l2: 1.09821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6309]	valid_0's l1: 0.0327744	valid_0's l2: 1.09794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6310]	valid_0's l1: 0.0327728	valid_0's l2: 1.09768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6311]	valid_0's l1: 0.0327722	valid_0's l2: 1.09787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6312]	valid_0's l1: 0.0327716	valid_0's l2: 1.09807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6313]	valid_0's l1: 0.0327782	valid_0's l2: 1.09866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6314]	valid_0's l1: 0.0327776	valid_0's l2: 1.09886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6315]	valid_0's l1: 0.0327775	valid_0's l2: 1.09899
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6316]	valid_0's l1: 0.0327792	valid_0's l2: 1.09915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6317]	valid_0's l1: 0.0327809	valid_0's l2: 1.09929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6318]	valid_0's l1: 0.0327826	valid_0's l2: 1.09944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6319]	valid_0's l1: 0.0327843	valid_0's l2: 1.0996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6320]	valid_0's l1: 0.0327844	valid_0's l2: 1.0998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6321]	valid_0's l1: 0.032783	valid_0's l2: 1.09936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6322]	valid_0's l1: 0.0327816	valid_0's l2: 1.09893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6323]	valid_0's l1: 0.0327802	valid_0's l2: 1.0985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6324]	valid_0's l1: 0.0327789	valid_0's l2: 1.09807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6325]	valid_0's l1: 0.0327775	valid_0's l2: 1.09765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6326]	valid_0's l1: 0.0327764	valid_0's l2: 1.09723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6327]	valid_0's l1: 0.0327748	valid_0's l2: 1.0968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6328]	valid_0's l1: 0.0327735	valid_0's l2: 1.09639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6329]	valid_0's l1: 0.0327741	valid_0's l2: 1.09609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6330]	valid_0's l1: 0.032773	valid_0's l2: 1.09569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6331]	valid_0's l1: 0.0327708	valid_0's l2: 1.09544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6332]	valid_0's l1: 0.0327697	valid_0's l2: 1.09519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6333]	valid_0's l1: 0.0327675	valid_0's l2: 1.09494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6334]	valid_0's l1: 0.0327653	valid_0's l2: 1.09469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6335]	valid_0's l1: 0.0327644	valid_0's l2: 1.09444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6336]	valid_0's l1: 0.0327586	valid_0's l2: 1.09402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6337]	valid_0's l1: 0.0327561	valid_0's l2: 1.09358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6338]	valid_0's l1: 0.0327564	valid_0's l2: 1.09333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6339]	valid_0's l1: 0.0327491	valid_0's l2: 1.09292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6340]	valid_0's l1: 0.0327463	valid_0's l2: 1.09268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6341]	valid_0's l1: 0.0327499	valid_0's l2: 1.093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6342]	valid_0's l1: 0.0327537	valid_0's l2: 1.09332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6343]	valid_0's l1: 0.0327573	valid_0's l2: 1.09364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6344]	valid_0's l1: 0.032756	valid_0's l2: 1.09375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
y_pred = gbm.predict(x_train, num_iteration=gbm.best_iteration_)

# %%
# Basic RMSE
print('The rmse of prediction is:', round(mean_squared_log_error(y_pred, y_train) ** 0.5, 5))

# %%
# Results
test_pred = np.expm1(gbm.predict(df_test, num_iteration=gbm.best_iteration_))

# %%
df_test["item_cnt_day"] = test_pred
df_test.to_csv("results.csv", columns=["date_block_num", "item_cnt_day"], index=False)
